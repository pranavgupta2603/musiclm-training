# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavgupta2603/musiclm-training/blob/main/musiccaps_explorer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MusicCaps Explorer
#
# In this notebook, we see how you can use `yt-dlp` to download clips from the MusicCaps dataset from Google. The MusicCaps dataset contains music and their associated text captions. You could use a dataset such as this to train a nice text-to-audio generation model 😉!
#
# This notebook is 100% inspired and based on https://github.com/nateraw/download-musiccaps-dataset, with some additional annotations, so please give a star to that repo. The notebook shows how to load the dataset, underlying clips, and explore them.
#
# Let's get started! 🔥

# %% [markdown]
# ## Introduction and setup
#
# Let's kick things off by installing some dependencies and load the dataset. **Note that Kaggle comes with an old datasets version but we need a newer one, so you might need to restart the notebook after install to make sure it's using the last version.**

# %%
# %%capture
! pip install -U datasets[audio]
! pip install yt-dlp

# For the interactive interface we'll need gradio
! pip install gradio

# %% [markdown]
# We'll use the Hugging Face `datasets` library to load the dataset version hosted over there in the [google/MusicCaps](https://huggingface.co/datasets/google/MusicCaps) repository.

# %%
from datasets import load_dataset

ds = load_dataset('google/MusicCaps', split='train')
ds
# Out:
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/google___csv/google--MusicCaps-bedc2a0fd7888f2f/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1)
# Dataset({
#     features: ['ytid', 'start_s', 'end_s', 'audioset_positive_labels', 'aspect_list', 'caption', 'author_id', 'is_balanced_subset', 'is_audioset_eval'],
#     num_rows: 5521
# })

# %% [markdown]
# We see that there are 5,521 music samples. Each sample contains information such as the audio caption and a YouTube ID, which can be surprising. Rather than exposing the audio files directly, this dataset contains the ID of YouTube videos (`ytid` field) and the `start_s` and `end_s`, which indicate the time range of the video of the sample. This makes it a bit harder to work compared to other datasets.

# %% [markdown]
# ## Loading audio data
#
# As our goal is just loading some data and exploring it, we'll limit ourselves to load only 32 samples. Feel free to change the `samples_to_load` variable in the next cell, but take into account that it might take a long time for the whole dataset.Kaggle notebooks have 4 cores, so we can use that for our advantage too.
#
# Let's go and download the data! 🚀

# %%
# JUST HELPER METHODS IN THIS CELL 

import subprocess
import os
from pathlib import Path

def download_clip(
    video_identifier,
    output_filename,
    start_time,
    end_time,
    tmp_dir='/tmp/musiccaps',
    num_attempts=5,
    url_base='https://www.youtube.com/watch?v='
):
    status = False

    command = f"""
        yt-dlp --quiet --no-warnings -x --audio-format wav -f bestaudio -o "{output_filename}" --download-sections "*{start_time}-{end_time}" {url_base}{video_identifier}
    """.strip()

    attempts = 0
    while True:
        try:
            output = subprocess.check_output(command, shell=True,
                                                stderr=subprocess.STDOUT)
        except subprocess.CalledProcessError as err:
            attempts += 1
            if attempts == num_attempts:
                return status, err.output
        else:
            break

    # Check if the video was successfully saved.
    status = os.path.exists(output_filename)
    return status, 'Downloaded'

def process(example):
    print("here")
    outfile_path = str(data_dir / f"{example['ytid']}.wav")
    status = True
    if not os.path.exists(outfile_path):
        status = False
        status, log = download_clip(
            example['ytid'],
            outfile_path,
            example['start_s'],
            example['end_s'],
        )

    example['audio'] = outfile_path
    example['download_status'] = status
    return example

# %%
from datasets import Audio

samples_to_load = 5521    # How many samples to load
cores = 4                 # How many processes to use for the loading
sampling_rate = 44100     # Sampling rate for the audio, keep in 44100
writer_batch_size = 1000  # How many examples to keep in memory per worker. Reduce if OOM.
data_dir = "./music_new_data" # Where to save the data

# Just select some samples 
#ds = ds.select(range(samples_to_load))

# Create directory where data will be saved
data_dir = Path(data_dir)
data_dir.mkdir(exist_ok=True, parents=True)

ds = ds.map(
        process,
        num_proc=cores,
        writer_batch_size=writer_batch_size,
        keep_in_memory=False
    ).cast_column('audio', Audio(sampling_rate=sampling_rate))
# Out:
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/google___csv/google--MusicCaps-bedc2a0fd7888f2f/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1/cache-0945dc51ed7c16f9_*_of_00004.arrow

# %%
# !zip music_data.zip ./music_new_data
# Out:
#   adding: music_new_data/ (stored 0%)

# %%
"""new_ds = []
try:

  ds1 = ds[:1800]
except:
  pass
ds2 = ds[1800:3600]
ds3 = ds[3600:]"""
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-6642bec1afab> in <cell line: 7>()
#       5 except:
#       6   pass
# ----> 7 ds2 = ds[1800:3600]
#       8 ds3 = ds[3600:]
#
# /usr/local/lib/python3.9/dist-packages/datasets/arrow_dataset.py in __getitem__(self, key)
#    2707     def __getitem__(self, key):  # noqa: F811
#    2708         """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2709         return self._getitem(key)
#    2710
#    2711     def __getitems__(self, keys: List) -> List:
#
# /usr/local/lib/python3.9/dist-packages/datasets/arrow_dataset.py in _getitem(self, key, **kwargs)
#    2692         formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
#    2693         pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
# -> 2694         formatted_output = format_table(
#    2695             pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    2696         )
#
# /usr/local/lib/python3.9/dist-packages/datasets/formatting/formatting.py in format_table(table, key, formatter, format_columns, output_all_columns)
#     632     python_formatter = PythonFormatter(features=None)
#     633     if format_columns is None:
# --> 634         return formatter(pa_table, query_type=query_type)
#     635     elif query_type == "column":
#     636         if key in format_columns:
#
# /usr/local/lib/python3.9/dist-packages/datasets/formatting/formatting.py in __call__(self, pa_table, query_type)
#     408             return self.format_column(pa_table)
#     409         elif query_type == "batch":
# --> 410             return self.format_batch(pa_table)
#     411
#     412     def format_row(self, pa_table: pa.Table) -> RowFormat:
#
# /usr/local/lib/python3.9/dist-packages/datasets/formatting/formatting.py in format_batch(self, pa_table)
#     452             return LazyBatch(pa_table, self)
#     453         batch = self.python_arrow_extractor().extract_batch(pa_table)
# --> 454         batch = self.python_features_decoder.decode_batch(batch)
#     455         return batch
#     456
#
# /usr/local/lib/python3.9/dist-packages/datasets/formatting/formatting.py in decode_batch(self, batch)
#     229
#     230     def decode_batch(self, batch: dict) -> dict:
# --> 231         return self.features.decode_batch(batch) if self.features else batch
#     232
#     233
#
# /usr/local/lib/python3.9/dist-packages/datasets/features/features.py in decode_batch(self, batch, token_per_repo_id)
#    1905         for column_name, column in batch.items():
#    1906             decoded_batch[column_name] = (
# -> 1907                 [
#    1908                     decode_nested_example(self[column_name], value, token_per_repo_id=token_per_repo_id)
#    1909                     if value is not None
#
# /usr/local/lib/python3.9/dist-packages/datasets/features/features.py in <listcomp>(.0)
#    1906             decoded_batch[column_name] = (
#    1907                 [
# -> 1908                     decode_nested_example(self[column_name], value, token_per_repo_id=token_per_repo_id)
#    1909                     if value is not None
#    1910                     else None
#
# /usr/local/lib/python3.9/dist-packages/datasets/features/features.py in decode_nested_example(schema, obj, token_per_repo_id)
#    1306         # we pass the token to read and decode files from private repositories in streaming mode
#    1307         if obj is not None and schema.decode:
# -> 1308             return schema.decode_example(obj, token_per_repo_id=token_per_repo_id)
#    1309     return obj
#    1310
#
# /usr/local/lib/python3.9/dist-packages/datasets/features/audio.py in decode_example(self, value, token_per_repo_id)
#     179                 use_auth_token = None
#     180
# --> 181             with xopen(path, "rb", use_auth_token=use_auth_token) as f:
#     182                 array, sampling_rate = sf.read(f)
#     183
#
# /usr/local/lib/python3.9/dist-packages/datasets/download/streaming_download_manager.py in xopen(file, mode, use_auth_token, *args, **kwargs)
#     483     main_hop, *rest_hops = file_str.split("::")
#     484     if is_local_path(main_hop):
# --> 485         return open(main_hop, mode, *args, **kwargs)
#     486     # add headers and cookies for authentication on the HF Hub and for Google Drive
#     487     if not rest_hops and (main_hop.startswith("http://") or main_hop.startswith("https://")):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'music_new_data/IbJh1xeBFcI.wav'

# %%
for i in range(ds1):
  try:
    new_ds.append(ds1[i])
  except:
    pass

# %%
for i in range(ds2):
  try:
    new_ds.append(ds2[i])
  except:
    pass

# %%
for i in range(ds3):
  try:
    new_ds.append(ds3[i])
  except:
    pass

# %% [markdown]
# Done! Let's look at the data of an example

# %%
ds[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d4162fd57828> in <cell line: 1>()
# ----> 1 ds[0]
#
# NameError: name 'ds' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cp -av "./drive/MyDrive/music_new_data" "./music_new_data"
# Out:
# './drive/MyDrive/music_new_data' -> './music_new_data'
# './drive/MyDrive/music_new_data/CaCjiFUL6Fg.wav' -> './music_new_data/CaCjiFUL6Fg.wav'
# './drive/MyDrive/music_new_data/-0Gj8-vB1q4.wav' -> './music_new_data/-0Gj8-vB1q4.wav'
# './drive/MyDrive/music_new_data/hoPnrbKOEl8.wav' -> './music_new_data/hoPnrbKOEl8.wav'
# './drive/MyDrive/music_new_data/hpiFoinUgvY.wav' -> './music_new_data/hpiFoinUgvY.wav'
# './drive/MyDrive/music_new_data/Cchf2QH63bI.wav' -> './music_new_data/Cchf2QH63bI.wav'
# './drive/MyDrive/music_new_data/hrCf8rMBtA8.wav' -> './music_new_data/hrCf8rMBtA8.wav'
# './drive/MyDrive/music_new_data/-0vPFx-wRRI.wav' -> './music_new_data/-0vPFx-wRRI.wav'
# './drive/MyDrive/music_new_data/hqQvatf1RUY.wav' -> './music_new_data/hqQvatf1RUY.wav'
# './drive/MyDrive/music_new_data/Cd7JefC6-Zw.wav' -> './music_new_data/Cd7JefC6-Zw.wav'
# './drive/MyDrive/music_new_data/hqCJarP-nVI.wav' -> './music_new_data/hqCJarP-nVI.wav'
# './drive/MyDrive/music_new_data/-0SdAVK79lg.wav' -> './music_new_data/-0SdAVK79lg.wav'
# './drive/MyDrive/music_new_data/CdFutCUKTXI.wav' -> './music_new_data/CdFutCUKTXI.wav'
# './drive/MyDrive/music_new_data/CdWA-SNcYpM.wav' -> './music_new_data/CdWA-SNcYpM.wav'
# './drive/MyDrive/music_new_data/SMjYheNdAzg.wav' -> './music_new_data/SMjYheNdAzg.wav'
# './drive/MyDrive/music_new_data/hrOP9swUpyA.wav' -> './music_new_data/hrOP9swUpyA.wav'
# './drive/MyDrive/music_new_data/CdgQIiMdBa4.wav' -> './music_new_data/CdgQIiMdBa4.wav'
# './drive/MyDrive/music_new_data/-0xzrMun0Rs.wav' -> './music_new_data/-0xzrMun0Rs.wav'
# './drive/MyDrive/music_new_data/SNhfvhWPXNc.wav' -> './music_new_data/SNhfvhWPXNc.wav'
# './drive/MyDrive/music_new_data/hvmCuosF0Xo.wav' -> './music_new_data/hvmCuosF0Xo.wav'
# './drive/MyDrive/music_new_data/Ce-Xok6SRPU.wav' -> './music_new_data/Ce-Xok6SRPU.wav'
# './drive/MyDrive/music_new_data/hu5pjj1KzK8.wav' -> './music_new_data/hu5pjj1KzK8.wav'
# './drive/MyDrive/music_new_data/SOzuJU25uGc.wav' -> './music_new_data/SOzuJU25uGc.wav'
# './drive/MyDrive/music_new_data/CeaWlENtRio.wav' -> './music_new_data/CeaWlENtRio.wav'
# './drive/MyDrive/music_new_data/-1LrH01Ei1w.wav' -> './music_new_data/-1LrH01Ei1w.wav'
# './drive/MyDrive/music_new_data/hu6sChY-Yps.wav' -> './music_new_data/hu6sChY-Yps.wav'
# './drive/MyDrive/music_new_data/SPeGy815lFQ.wav' -> './music_new_data/SPeGy815lFQ.wav'
# './drive/MyDrive/music_new_data/Cf1zNtZEcc8.wav' -> './music_new_data/Cf1zNtZEcc8.wav'
# './drive/MyDrive/music_new_data/-1OlgJWehn8.wav' -> './music_new_data/-1OlgJWehn8.wav'
# './drive/MyDrive/music_new_data/SSO7F_Ex0s4.wav' -> './music_new_data/SSO7F_Ex0s4.wav'
# './drive/MyDrive/music_new_data/CfRzy-RtqnQ.wav' -> './music_new_data/CfRzy-RtqnQ.wav'
# './drive/MyDrive/music_new_data/-1UWSisR2zo.wav' -> './music_new_data/-1UWSisR2zo.wav'
# './drive/MyDrive/music_new_data/CgK0DU3KFBc.wav' -> './music_new_data/CgK0DU3KFBc.wav'
# './drive/MyDrive/music_new_data/SSVlD_ZDb70.wav' -> './music_new_data/SSVlD_ZDb70.wav'
# './drive/MyDrive/music_new_data/-3Kv4fdm7Uk.wav' -> './music_new_data/-3Kv4fdm7Uk.wav'
# './drive/MyDrive/music_new_data/SUclDZHax0w.wav' -> './music_new_data/SUclDZHax0w.wav'
# './drive/MyDrive/music_new_data/hwSOjoHFLn4.wav' -> './music_new_data/hwSOjoHFLn4.wav'
# './drive/MyDrive/music_new_data/SU9ZP2pbqyU.wav' -> './music_new_data/SU9ZP2pbqyU.wav'
# './drive/MyDrive/music_new_data/-4NLarMj4xU.wav' -> './music_new_data/-4NLarMj4xU.wav'
# './drive/MyDrive/music_new_data/ChCdYoDz7CY.wav' -> './music_new_data/ChCdYoDz7CY.wav'
# './drive/MyDrive/music_new_data/SW4cW2oU07U.wav' -> './music_new_data/SW4cW2oU07U.wav'
# './drive/MyDrive/music_new_data/hwe6y-jSqdQ.wav' -> './music_new_data/hwe6y-jSqdQ.wav'
# './drive/MyDrive/music_new_data/ChqJYrmQIN4.wav' -> './music_new_data/ChqJYrmQIN4.wav'
# './drive/MyDrive/music_new_data/-4SYC2YgzL8.wav' -> './music_new_data/-4SYC2YgzL8.wav'
# './drive/MyDrive/music_new_data/Ck-1kRnHqro.wav' -> './music_new_data/Ck-1kRnHqro.wav'
# './drive/MyDrive/music_new_data/hwp7wCKIXg4.wav' -> './music_new_data/hwp7wCKIXg4.wav'
# './drive/MyDrive/music_new_data/-5FoeegAgvU.wav' -> './music_new_data/-5FoeegAgvU.wav'
# './drive/MyDrive/music_new_data/ChyayWIp_vU.wav' -> './music_new_data/ChyayWIp_vU.wav'
# './drive/MyDrive/music_new_data/hyGuS5WiPk8.wav' -> './music_new_data/hyGuS5WiPk8.wav'
# './drive/MyDrive/music_new_data/SWcEG8RLKsw.wav' -> './music_new_data/SWcEG8RLKsw.wav'
# './drive/MyDrive/music_new_data/-5f6hjZf9Yw.wav' -> './music_new_data/-5f6hjZf9Yw.wav'
# './drive/MyDrive/music_new_data/i3zayf6Hiog.wav' -> './music_new_data/i3zayf6Hiog.wav'
# './drive/MyDrive/music_new_data/hzr2aY33EuI.wav' -> './music_new_data/hzr2aY33EuI.wav'
# './drive/MyDrive/music_new_data/SWyF5TSxWso.wav' -> './music_new_data/SWyF5TSxWso.wav'
# './drive/MyDrive/music_new_data/hzznbzry5R8.wav' -> './music_new_data/hzznbzry5R8.wav'
# './drive/MyDrive/music_new_data/-5xOcMJpTUk.wav' -> './music_new_data/-5xOcMJpTUk.wav'
# './drive/MyDrive/music_new_data/Ck_bvV8Aa-k.wav' -> './music_new_data/Ck_bvV8Aa-k.wav'
# './drive/MyDrive/music_new_data/SY6uwVbC944.wav' -> './music_new_data/SY6uwVbC944.wav'
# './drive/MyDrive/music_new_data/SYVcaQ1Bzu8.wav' -> './music_new_data/SYVcaQ1Bzu8.wav'
# './drive/MyDrive/music_new_data/CkgzMSbE68M.wav' -> './music_new_data/CkgzMSbE68M.wav'
# './drive/MyDrive/music_new_data/-6HBGg1cAI0.wav' -> './music_new_data/-6HBGg1cAI0.wav'
# './drive/MyDrive/music_new_data/i6WtNBpRll0.wav' -> './music_new_data/i6WtNBpRll0.wav'
# './drive/MyDrive/music_new_data/ClK_qf_Twm8.wav' -> './music_new_data/ClK_qf_Twm8.wav'
# './drive/MyDrive/music_new_data/CodqNx1ukOc.wav' -> './music_new_data/CodqNx1ukOc.wav'
# './drive/MyDrive/music_new_data/S_Z7o4OmU30.wav' -> './music_new_data/S_Z7o4OmU30.wav'
# './drive/MyDrive/music_new_data/i6dFcfV64RE.wav' -> './music_new_data/i6dFcfV64RE.wav'
# './drive/MyDrive/music_new_data/ClNTn1wtq7E.wav' -> './music_new_data/ClNTn1wtq7E.wav'
# './drive/MyDrive/music_new_data/Sa3Ky5sJshU.wav' -> './music_new_data/Sa3Ky5sJshU.wav'
# './drive/MyDrive/music_new_data/-6QGvxvaTkI.wav' -> './music_new_data/-6QGvxvaTkI.wav'
# './drive/MyDrive/music_new_data/Cn3xoxvbkF0.wav' -> './music_new_data/Cn3xoxvbkF0.wav'
# './drive/MyDrive/music_new_data/SbUwQctvbHg.wav' -> './music_new_data/SbUwQctvbHg.wav'
# './drive/MyDrive/music_new_data/CnTMm-bzssM.wav' -> './music_new_data/CnTMm-bzssM.wav'
# './drive/MyDrive/music_new_data/i6k1yiyO5jQ.wav' -> './music_new_data/i6k1yiyO5jQ.wav'
# './drive/MyDrive/music_new_data/ScAlKYCgHV0.wav' -> './music_new_data/ScAlKYCgHV0.wav'
# './drive/MyDrive/music_new_data/CpHRQ-f4UtA.wav' -> './music_new_data/CpHRQ-f4UtA.wav'
# './drive/MyDrive/music_new_data/i70a79YhlMk.wav' -> './music_new_data/i70a79YhlMk.wav'
# './drive/MyDrive/music_new_data/Sdnv8043mdk.wav' -> './music_new_data/Sdnv8043mdk.wav'
# './drive/MyDrive/music_new_data/CphwhKgYHaM.wav' -> './music_new_data/CphwhKgYHaM.wav'
# './drive/MyDrive/music_new_data/i8PFu7AiwaE.wav' -> './music_new_data/i8PFu7AiwaE.wav'
# './drive/MyDrive/music_new_data/-6pcgdLfb_A.wav' -> './music_new_data/-6pcgdLfb_A.wav'
# './drive/MyDrive/music_new_data/SijRZIQUa08.wav' -> './music_new_data/SijRZIQUa08.wav'
# './drive/MyDrive/music_new_data/CqtknE729Lw.wav' -> './music_new_data/CqtknE729Lw.wav'
# './drive/MyDrive/music_new_data/i8bt6Mb0rUc.wav' -> './music_new_data/i8bt6Mb0rUc.wav'
# './drive/MyDrive/music_new_data/-7B9tPuIP-w.wav' -> './music_new_data/-7B9tPuIP-w.wav'
# './drive/MyDrive/music_new_data/Simd4JoehW8.wav' -> './music_new_data/Simd4JoehW8.wav'
# './drive/MyDrive/music_new_data/-8C-gydUbR8.wav' -> './music_new_data/-8C-gydUbR8.wav'
# './drive/MyDrive/music_new_data/-7wUQP6G5EQ.wav' -> './music_new_data/-7wUQP6G5EQ.wav'
# './drive/MyDrive/music_new_data/Sj5MQtqDw8Y.wav' -> './music_new_data/Sj5MQtqDw8Y.wav'
# './drive/MyDrive/music_new_data/iBH5X5SKirU.wav' -> './music_new_data/iBH5X5SKirU.wav'
# './drive/MyDrive/music_new_data/CrbZHPkHeV4.wav' -> './music_new_data/CrbZHPkHeV4.wav'
# './drive/MyDrive/music_new_data/-88me9bBzrk.wav' -> './music_new_data/-88me9bBzrk.wav'
# './drive/MyDrive/music_new_data/SkFG5SoXsVk.wav' -> './music_new_data/SkFG5SoXsVk.wav'
# './drive/MyDrive/music_new_data/iBezxlI_f_c.wav' -> './music_new_data/iBezxlI_f_c.wav'
# './drive/MyDrive/music_new_data/CretxKgW4Jk.wav' -> './music_new_data/CretxKgW4Jk.wav'
# './drive/MyDrive/music_new_data/-ByoSbgzr4M.wav' -> './music_new_data/-ByoSbgzr4M.wav'
# './drive/MyDrive/music_new_data/SkIDF7iNJQE.wav' -> './music_new_data/SkIDF7iNJQE.wav'
# './drive/MyDrive/music_new_data/iBh37YAaHMU.wav' -> './music_new_data/iBh37YAaHMU.wav'
# './drive/MyDrive/music_new_data/-8cgbhIR_pw.wav' -> './music_new_data/-8cgbhIR_pw.wav'
# './drive/MyDrive/music_new_data/SvsCM0fLM5g.wav' -> './music_new_data/SvsCM0fLM5g.wav'
# './drive/MyDrive/music_new_data/SkZ7mGbs3SI.wav' -> './music_new_data/SkZ7mGbs3SI.wav'
# './drive/MyDrive/music_new_data/iCHskFoUvbw.wav' -> './music_new_data/iCHskFoUvbw.wav'
# './drive/MyDrive/music_new_data/-BHPu-dPmWQ.wav' -> './music_new_data/-BHPu-dPmWQ.wav'
# './drive/MyDrive/music_new_data/Sl9ZkYViEIs.wav' -> './music_new_data/Sl9ZkYViEIs.wav'
# './drive/MyDrive/music_new_data/iCIa_pmLDqs.wav' -> './music_new_data/iCIa_pmLDqs.wav'
# './drive/MyDrive/music_new_data/-BIMKnb3tlo.wav' -> './music_new_data/-BIMKnb3tlo.wav'
# './drive/MyDrive/music_new_data/SlnjJv305Vg.wav' -> './music_new_data/SlnjJv305Vg.wav'
# './drive/MyDrive/music_new_data/iDvva_WCo-I.wav' -> './music_new_data/iDvva_WCo-I.wav'
# './drive/MyDrive/music_new_data/-Bu7YaslRW0.wav' -> './music_new_data/-Bu7YaslRW0.wav'
# './drive/MyDrive/music_new_data/Sp1YBy4h9OY.wav' -> './music_new_data/Sp1YBy4h9OY.wav'
# './drive/MyDrive/music_new_data/CrjSYvGWusQ.wav' -> './music_new_data/CrjSYvGWusQ.wav'
# './drive/MyDrive/music_new_data/iEMTTKA7NxU.wav' -> './music_new_data/iEMTTKA7NxU.wav'
# './drive/MyDrive/music_new_data/Sp3T_x3SGzQ.wav' -> './music_new_data/Sp3T_x3SGzQ.wav'
# './drive/MyDrive/music_new_data/CrkxrgTiVyk.wav' -> './music_new_data/CrkxrgTiVyk.wav'
# './drive/MyDrive/music_new_data/iEQwupwwp0s.wav' -> './music_new_data/iEQwupwwp0s.wav'
# './drive/MyDrive/music_new_data/-CUp_Tmg2Y0.wav' -> './music_new_data/-CUp_Tmg2Y0.wav'
# './drive/MyDrive/music_new_data/Sr2Grfi3lFg.wav' -> './music_new_data/Sr2Grfi3lFg.wav'
# './drive/MyDrive/music_new_data/-DeAdhYKbGE.wav' -> './music_new_data/-DeAdhYKbGE.wav'
# './drive/MyDrive/music_new_data/iEcWlreXhGc.wav' -> './music_new_data/iEcWlreXhGc.wav'
# './drive/MyDrive/music_new_data/CtcmYF7mufk.wav' -> './music_new_data/CtcmYF7mufk.wav'
# './drive/MyDrive/music_new_data/SrLhnoBMyWM.wav' -> './music_new_data/SrLhnoBMyWM.wav'
# './drive/MyDrive/music_new_data/Ss1bubMNPQE.wav' -> './music_new_data/Ss1bubMNPQE.wav'
# './drive/MyDrive/music_new_data/CuUu6L5hhMs.wav' -> './music_new_data/CuUu6L5hhMs.wav'
# './drive/MyDrive/music_new_data/CwImmV7q1MY.wav' -> './music_new_data/CwImmV7q1MY.wav'
# './drive/MyDrive/music_new_data/iFSaNmZyPQo.wav' -> './music_new_data/iFSaNmZyPQo.wav'
# './drive/MyDrive/music_new_data/CudxWnS7ukw.wav' -> './music_new_data/CudxWnS7ukw.wav'
# './drive/MyDrive/music_new_data/iFWtsT5zRKo.wav' -> './music_new_data/iFWtsT5zRKo.wav'
# './drive/MyDrive/music_new_data/SsVc1TAVsSc.wav' -> './music_new_data/SsVc1TAVsSc.wav'
# './drive/MyDrive/music_new_data/CwHSb1NOi4c.wav' -> './music_new_data/CwHSb1NOi4c.wav'
# './drive/MyDrive/music_new_data/-FEPOSP7ay0.wav' -> './music_new_data/-FEPOSP7ay0.wav'
# './drive/MyDrive/music_new_data/iHXUaVWi7kE.wav' -> './music_new_data/iHXUaVWi7kE.wav'
# './drive/MyDrive/music_new_data/-Dtir74TiUM.wav' -> './music_new_data/-Dtir74TiUM.wav'
# './drive/MyDrive/music_new_data/SwRjY1-ojAU.wav' -> './music_new_data/SwRjY1-ojAU.wav'
# './drive/MyDrive/music_new_data/iHYOaGNdweo.wav' -> './music_new_data/iHYOaGNdweo.wav'
# './drive/MyDrive/music_new_data/CwmUMySSNQc.wav' -> './music_new_data/CwmUMySSNQc.wav'
# './drive/MyDrive/music_new_data/Cwbtn_h6TP8.wav' -> './music_new_data/Cwbtn_h6TP8.wav'
# './drive/MyDrive/music_new_data/-EVRXQpt1-8.wav' -> './music_new_data/-EVRXQpt1-8.wav'
# './drive/MyDrive/music_new_data/iLIBaMceZQc.wav' -> './music_new_data/iLIBaMceZQc.wav'
# './drive/MyDrive/music_new_data/SwaqANBpZGY.wav' -> './music_new_data/SwaqANBpZGY.wav'
# './drive/MyDrive/music_new_data/SxYnb9_qDtk.wav' -> './music_new_data/SxYnb9_qDtk.wav'
# './drive/MyDrive/music_new_data/CxTFgimfNfA.wav' -> './music_new_data/CxTFgimfNfA.wav'
# './drive/MyDrive/music_new_data/iMTHDuW_xKc.wav' -> './music_new_data/iMTHDuW_xKc.wav'
# './drive/MyDrive/music_new_data/SwdhfGXkMCo.wav' -> './music_new_data/SwdhfGXkMCo.wav'
# './drive/MyDrive/music_new_data/iMmYVLSb1IY.wav' -> './music_new_data/iMmYVLSb1IY.wav'
# './drive/MyDrive/music_new_data/CxgVq6eovRU.wav' -> './music_new_data/CxgVq6eovRU.wav'
# './drive/MyDrive/music_new_data/Swien0oGl7o.wav' -> './music_new_data/Swien0oGl7o.wav'
# './drive/MyDrive/music_new_data/-FFx68qSAuY.wav' -> './music_new_data/-FFx68qSAuY.wav'
# './drive/MyDrive/music_new_data/iP46w2o_HCk.wav' -> './music_new_data/iP46w2o_HCk.wav'
# './drive/MyDrive/music_new_data/-FlvaZQOr2I.wav' -> './music_new_data/-FlvaZQOr2I.wav'
# './drive/MyDrive/music_new_data/-Gf4Ihv1zwc.wav' -> './music_new_data/-Gf4Ihv1zwc.wav'
# './drive/MyDrive/music_new_data/SyJT8XsFsmE.wav' -> './music_new_data/SyJT8XsFsmE.wav'
# './drive/MyDrive/music_new_data/Cy3HWnwMLyI.wav' -> './music_new_data/Cy3HWnwMLyI.wav'
# './drive/MyDrive/music_new_data/iQ7qeIrssds.wav' -> './music_new_data/iQ7qeIrssds.wav'
# './drive/MyDrive/music_new_data/-IZbvEO9wzU.wav' -> './music_new_data/-IZbvEO9wzU.wav'
# './drive/MyDrive/music_new_data/CyFsI_EYFQQ.wav' -> './music_new_data/CyFsI_EYFQQ.wav'
# './drive/MyDrive/music_new_data/CyiPyjYX6AE.wav' -> './music_new_data/CyiPyjYX6AE.wav'
# './drive/MyDrive/music_new_data/iQAXwX28LLw.wav' -> './music_new_data/iQAXwX28LLw.wav'
# './drive/MyDrive/music_new_data/T0OFKHj6878.wav' -> './music_new_data/T0OFKHj6878.wav'
# './drive/MyDrive/music_new_data/-JvB5AL59fM.wav' -> './music_new_data/-JvB5AL59fM.wav'
# './drive/MyDrive/music_new_data/iQJvAXOohoU.wav' -> './music_new_data/iQJvAXOohoU.wav'
# './drive/MyDrive/music_new_data/-JVWfFPBl84.wav' -> './music_new_data/-JVWfFPBl84.wav'
# './drive/MyDrive/music_new_data/T0oF8MyYhBM.wav' -> './music_new_data/T0oF8MyYhBM.wav'
# './drive/MyDrive/music_new_data/iS-iTbHndw8.wav' -> './music_new_data/iS-iTbHndw8.wav'
# './drive/MyDrive/music_new_data/T0tyLNN7SKA.wav' -> './music_new_data/T0tyLNN7SKA.wav'
# './drive/MyDrive/music_new_data/CzHZNJEV-3o.wav' -> './music_new_data/CzHZNJEV-3o.wav'
# './drive/MyDrive/music_new_data/iQfPmJ19ZUc.wav' -> './music_new_data/iQfPmJ19ZUc.wav'
# './drive/MyDrive/music_new_data/CzMNiypg1I8.wav' -> './music_new_data/CzMNiypg1I8.wav'
# './drive/MyDrive/music_new_data/T2pIUdaDMuA.wav' -> './music_new_data/T2pIUdaDMuA.wav'
# './drive/MyDrive/music_new_data/-O9mnfC61Ac.wav' -> './music_new_data/-O9mnfC61Ac.wav'
# './drive/MyDrive/music_new_data/-M-6VinyMiY.wav' -> './music_new_data/-M-6VinyMiY.wav'
# './drive/MyDrive/music_new_data/T0uoYE12cnI.wav' -> './music_new_data/T0uoYE12cnI.wav'
# './drive/MyDrive/music_new_data/Czbi1u-gwUU.wav' -> './music_new_data/Czbi1u-gwUU.wav'
# './drive/MyDrive/music_new_data/iS8YQGp2_ng.wav' -> './music_new_data/iS8YQGp2_ng.wav'
# './drive/MyDrive/music_new_data/-M6K3QoHh40.wav' -> './music_new_data/-M6K3QoHh40.wav'
# './drive/MyDrive/music_new_data/T2zoWLYzEpo.wav' -> './music_new_data/T2zoWLYzEpo.wav'
# './drive/MyDrive/music_new_data/D-PxXM2I5gY.wav' -> './music_new_data/D-PxXM2I5gY.wav'
# './drive/MyDrive/music_new_data/iSETDHfErjU.wav' -> './music_new_data/iSETDHfErjU.wav'
# './drive/MyDrive/music_new_data/T5YZwhC7Br8.wav' -> './music_new_data/T5YZwhC7Br8.wav'
# './drive/MyDrive/music_new_data/-NmjCyqIavI.wav' -> './music_new_data/-NmjCyqIavI.wav'
# './drive/MyDrive/music_new_data/iSw-5EjXgXc.wav' -> './music_new_data/iSw-5EjXgXc.wav'
# './drive/MyDrive/music_new_data/D-p9s8y2z_U.wav' -> './music_new_data/D-p9s8y2z_U.wav'
# './drive/MyDrive/music_new_data/-OAyRsvFGgc.wav' -> './music_new_data/-OAyRsvFGgc.wav'
# './drive/MyDrive/music_new_data/-OUIEnuNd1I.wav' -> './music_new_data/-OUIEnuNd1I.wav'
# './drive/MyDrive/music_new_data/D0L-M4trkpw.wav' -> './music_new_data/D0L-M4trkpw.wav'
# './drive/MyDrive/music_new_data/iTV3Otwq_dI.wav' -> './music_new_data/iTV3Otwq_dI.wav'
# './drive/MyDrive/music_new_data/D2w3qHmJrdU.wav' -> './music_new_data/D2w3qHmJrdU.wav'
# './drive/MyDrive/music_new_data/T7khbuOBHbo.wav' -> './music_new_data/T7khbuOBHbo.wav'
# './drive/MyDrive/music_new_data/D3f5VIJYR7M.wav' -> './music_new_data/D3f5VIJYR7M.wav'
# './drive/MyDrive/music_new_data/D3FyfFIKLVc.wav' -> './music_new_data/D3FyfFIKLVc.wav'
# './drive/MyDrive/music_new_data/T78nMdsJMmk.wav' -> './music_new_data/T78nMdsJMmk.wav'
# './drive/MyDrive/music_new_data/-Q9MTRXS4bE.wav' -> './music_new_data/-Q9MTRXS4bE.wav'
# './drive/MyDrive/music_new_data/D3ht_xXl5S0.wav' -> './music_new_data/D3ht_xXl5S0.wav'
# './drive/MyDrive/music_new_data/T7A0RejsZIo.wav' -> './music_new_data/T7A0RejsZIo.wav'
# './drive/MyDrive/music_new_data/-QuWdnmn-kM.wav' -> './music_new_data/-QuWdnmn-kM.wav'
# './drive/MyDrive/music_new_data/iTWZsfVCyBs.wav' -> './music_new_data/iTWZsfVCyBs.wav'
# './drive/MyDrive/music_new_data/T7ZSZhcsfjA.wav' -> './music_new_data/T7ZSZhcsfjA.wav'
# './drive/MyDrive/music_new_data/-R0267o4lLk.wav' -> './music_new_data/-R0267o4lLk.wav'
# './drive/MyDrive/music_new_data/D3q_stCeCA8.wav' -> './music_new_data/D3q_stCeCA8.wav'
# './drive/MyDrive/music_new_data/T7bG4kIEw-M.wav' -> './music_new_data/T7bG4kIEw-M.wav'
# './drive/MyDrive/music_new_data/-RYtUAsNhF0.wav' -> './music_new_data/-RYtUAsNhF0.wav'
# './drive/MyDrive/music_new_data/iX53Jb72Nwk.wav' -> './music_new_data/iX53Jb72Nwk.wav'
# './drive/MyDrive/music_new_data/D4GVgBX1eYc.wav' -> './music_new_data/D4GVgBX1eYc.wav'
# './drive/MyDrive/music_new_data/iUHqyjf3NcQ.wav' -> './music_new_data/iUHqyjf3NcQ.wav'
# './drive/MyDrive/music_new_data/D6xrH93lnoc.wav' -> './music_new_data/D6xrH93lnoc.wav'
# './drive/MyDrive/music_new_data/D4ccFYk3bhU.wav' -> './music_new_data/D4ccFYk3bhU.wav'
# './drive/MyDrive/music_new_data/T8U3ihbHh9A.wav' -> './music_new_data/T8U3ihbHh9A.wav'
# './drive/MyDrive/music_new_data/iUxy2s5d60o.wav' -> './music_new_data/iUxy2s5d60o.wav'
# './drive/MyDrive/music_new_data/iVBNoH6XgW4.wav' -> './music_new_data/iVBNoH6XgW4.wav'
# './drive/MyDrive/music_new_data/T9dKp1EN4p8.wav' -> './music_new_data/T9dKp1EN4p8.wav'
# './drive/MyDrive/music_new_data/D644BWAUOXo.wav' -> './music_new_data/D644BWAUOXo.wav'
# './drive/MyDrive/music_new_data/TC4mH6nACm8.wav' -> './music_new_data/TC4mH6nACm8.wav'
# './drive/MyDrive/music_new_data/T9fk99yqwN4.wav' -> './music_new_data/T9fk99yqwN4.wav'
# './drive/MyDrive/music_new_data/-SD43H5B5hE.wav' -> './music_new_data/-SD43H5B5hE.wav'
# './drive/MyDrive/music_new_data/-SWaCArvQug.wav' -> './music_new_data/-SWaCArvQug.wav'
# './drive/MyDrive/music_new_data/TA-O_bVnvLY.wav' -> './music_new_data/TA-O_bVnvLY.wav'
# './drive/MyDrive/music_new_data/D712KM8PE3I.wav' -> './music_new_data/D712KM8PE3I.wav'
# './drive/MyDrive/music_new_data/iX_a2Ct0ya8.wav' -> './music_new_data/iX_a2Ct0ya8.wav'
# './drive/MyDrive/music_new_data/-T4GeTHKtJQ.wav' -> './music_new_data/-T4GeTHKtJQ.wav'
# './drive/MyDrive/music_new_data/TArWNq2retM.wav' -> './music_new_data/TArWNq2retM.wav'
# './drive/MyDrive/music_new_data/D7Cvisf3jf8.wav' -> './music_new_data/D7Cvisf3jf8.wav'
# './drive/MyDrive/music_new_data/D7pjR9cQChM.wav' -> './music_new_data/D7pjR9cQChM.wav'
# './drive/MyDrive/music_new_data/-UuEBhule84.wav' -> './music_new_data/-UuEBhule84.wav'
# './drive/MyDrive/music_new_data/TEWYFkjH2jc.wav' -> './music_new_data/TEWYFkjH2jc.wav'
# './drive/MyDrive/music_new_data/TCRxCAYyduo.wav' -> './music_new_data/TCRxCAYyduo.wav'
# './drive/MyDrive/music_new_data/-U16iKiXGuY.wav' -> './music_new_data/-U16iKiXGuY.wav'
# './drive/MyDrive/music_new_data/iYWvaxU5OXk.wav' -> './music_new_data/iYWvaxU5OXk.wav'
# './drive/MyDrive/music_new_data/-Umconw-CRE.wav' -> './music_new_data/-Umconw-CRE.wav'
# './drive/MyDrive/music_new_data/TEoDtxjlctA.wav' -> './music_new_data/TEoDtxjlctA.wav'
# './drive/MyDrive/music_new_data/THfTLXBLpJE.wav' -> './music_new_data/THfTLXBLpJE.wav'
# './drive/MyDrive/music_new_data/iZjIuV_cTe8.wav' -> './music_new_data/iZjIuV_cTe8.wav'
# './drive/MyDrive/music_new_data/D8-x1T8M4gk.wav' -> './music_new_data/D8-x1T8M4gk.wav'
# './drive/MyDrive/music_new_data/TFLt7mn57ZI.wav' -> './music_new_data/TFLt7mn57ZI.wav'
# './drive/MyDrive/music_new_data/TJyzBaMwXFY.wav' -> './music_new_data/TJyzBaMwXFY.wav'
# './drive/MyDrive/music_new_data/i_G_0vgEYJg.wav' -> './music_new_data/i_G_0vgEYJg.wav'
# './drive/MyDrive/music_new_data/ia6-da2KdI0.wav' -> './music_new_data/ia6-da2KdI0.wav'
# './drive/MyDrive/music_new_data/-VI2IRq17rs.wav' -> './music_new_data/-VI2IRq17rs.wav'
# './drive/MyDrive/music_new_data/i_NNY_mgxIs.wav' -> './music_new_data/i_NNY_mgxIs.wav'
# './drive/MyDrive/music_new_data/D8zK7PHIkgA.wav' -> './music_new_data/D8zK7PHIkgA.wav'
# './drive/MyDrive/music_new_data/i_d4JFg-zT0.wav' -> './music_new_data/i_d4JFg-zT0.wav'
# './drive/MyDrive/music_new_data/THhptTKMr9U.wav' -> './music_new_data/THhptTKMr9U.wav'
# './drive/MyDrive/music_new_data/D9893od03Sc.wav' -> './music_new_data/D9893od03Sc.wav'
# './drive/MyDrive/music_new_data/TIASpLtI8ks.wav' -> './music_new_data/TIASpLtI8ks.wav'
# './drive/MyDrive/music_new_data/TKSFbf-wQ8I.wav' -> './music_new_data/TKSFbf-wQ8I.wav'
# './drive/MyDrive/music_new_data/TIAj-fi_R7c.wav' -> './music_new_data/TIAj-fi_R7c.wav'
# './drive/MyDrive/music_new_data/iaDrtIon6FU.wav' -> './music_new_data/iaDrtIon6FU.wav'
# './drive/MyDrive/music_new_data/TIL8jEw8pSc.wav' -> './music_new_data/TIL8jEw8pSc.wav'
# './drive/MyDrive/music_new_data/-VclCul6FrI.wav' -> './music_new_data/-VclCul6FrI.wav'
# './drive/MyDrive/music_new_data/iaRDUksPv50.wav' -> './music_new_data/iaRDUksPv50.wav'
# './drive/MyDrive/music_new_data/-Vo4CAMX26U.wav' -> './music_new_data/-Vo4CAMX26U.wav'
# './drive/MyDrive/music_new_data/D9TuP8PKD6M.wav' -> './music_new_data/D9TuP8PKD6M.wav'
# './drive/MyDrive/music_new_data/iaonijK95qA.wav' -> './music_new_data/iaonijK95qA.wav'
# './drive/MyDrive/music_new_data/TPdqEmS1Dr0.wav' -> './music_new_data/TPdqEmS1Dr0.wav'
# './drive/MyDrive/music_new_data/-W5c6CeUMPE.wav' -> './music_new_data/-W5c6CeUMPE.wav'
# './drive/MyDrive/music_new_data/DA3fNvbZoBM.wav' -> './music_new_data/DA3fNvbZoBM.wav'
# './drive/MyDrive/music_new_data/ib8pMT_ug7o.wav' -> './music_new_data/ib8pMT_ug7o.wav'
# './drive/MyDrive/music_new_data/DA8lw6Mq0DY.wav' -> './music_new_data/DA8lw6Mq0DY.wav'
# './drive/MyDrive/music_new_data/TLMEsc_42Gw.wav' -> './music_new_data/TLMEsc_42Gw.wav'
# './drive/MyDrive/music_new_data/-WvVG0wHcTc.wav' -> './music_new_data/-WvVG0wHcTc.wav'
# './drive/MyDrive/music_new_data/icomsHXY8YA.wav' -> './music_new_data/icomsHXY8YA.wav'
# './drive/MyDrive/music_new_data/DAPGvg8qOAU.wav' -> './music_new_data/DAPGvg8qOAU.wav'
# './drive/MyDrive/music_new_data/TN53jpjqAGI.wav' -> './music_new_data/TN53jpjqAGI.wav'
# './drive/MyDrive/music_new_data/-XN0NtrnfMY.wav' -> './music_new_data/-XN0NtrnfMY.wav'
# './drive/MyDrive/music_new_data/id5ibIqjRto.wav' -> './music_new_data/id5ibIqjRto.wav'
# './drive/MyDrive/music_new_data/TObYoD2pGb0.wav' -> './music_new_data/TObYoD2pGb0.wav'
# './drive/MyDrive/music_new_data/-XkbErI_7EU.wav' -> './music_new_data/-XkbErI_7EU.wav'
# './drive/MyDrive/music_new_data/DAX9uKYlDvw.wav' -> './music_new_data/DAX9uKYlDvw.wav'
# './drive/MyDrive/music_new_data/idUZsNLnyDg.wav' -> './music_new_data/idUZsNLnyDg.wav'
# './drive/MyDrive/music_new_data/-YATTKBtmRA.wav' -> './music_new_data/-YATTKBtmRA.wav'
# './drive/MyDrive/music_new_data/-YIT4HBM__g.wav' -> './music_new_data/-YIT4HBM__g.wav'
# './drive/MyDrive/music_new_data/TPYNIc_M1ng.wav' -> './music_new_data/TPYNIc_M1ng.wav'
# './drive/MyDrive/music_new_data/DB38NRSHw9A.wav' -> './music_new_data/DB38NRSHw9A.wav'
# './drive/MyDrive/music_new_data/DCFrCX4HPO8.wav' -> './music_new_data/DCFrCX4HPO8.wav'
# './drive/MyDrive/music_new_data/DC0C-KO9EJk.wav' -> './music_new_data/DC0C-KO9EJk.wav'
# './drive/MyDrive/music_new_data/-ZHpNr_KRXU.wav' -> './music_new_data/-ZHpNr_KRXU.wav'
# './drive/MyDrive/music_new_data/-_6RxZyi30Q.wav' -> './music_new_data/-_6RxZyi30Q.wav'
# './drive/MyDrive/music_new_data/TSl5LrM6LcQ.wav' -> './music_new_data/TSl5LrM6LcQ.wav'
# './drive/MyDrive/music_new_data/ieEPKa3HiGo.wav' -> './music_new_data/ieEPKa3HiGo.wav'
# './drive/MyDrive/music_new_data/TTytcT_1dmY.wav' -> './music_new_data/TTytcT_1dmY.wav'
# './drive/MyDrive/music_new_data/DDZlMjb-0i4.wav' -> './music_new_data/DDZlMjb-0i4.wav'
# './drive/MyDrive/music_new_data/iePMcLYozYY.wav' -> './music_new_data/iePMcLYozYY.wav'
# './drive/MyDrive/music_new_data/-_OzT7Xyvok.wav' -> './music_new_data/-_OzT7Xyvok.wav'
# './drive/MyDrive/music_new_data/DE6bdmnmPtg.wav' -> './music_new_data/DE6bdmnmPtg.wav'
# './drive/MyDrive/music_new_data/-bgHkxwoliw.wav' -> './music_new_data/-bgHkxwoliw.wav'
# './drive/MyDrive/music_new_data/ihCl2ImrOYE.wav' -> './music_new_data/ihCl2ImrOYE.wav'
# './drive/MyDrive/music_new_data/TWV3YLscSaw.wav' -> './music_new_data/TWV3YLscSaw.wav'
# './drive/MyDrive/music_new_data/DEnayQZiPGc.wav' -> './music_new_data/DEnayQZiPGc.wav'
# './drive/MyDrive/music_new_data/-cQ-jUTEgck.wav' -> './music_new_data/-cQ-jUTEgck.wav'
# './drive/MyDrive/music_new_data/DG5d4megH8g.wav' -> './music_new_data/DG5d4megH8g.wav'
# './drive/MyDrive/music_new_data/TWm0OilO0uw.wav' -> './music_new_data/TWm0OilO0uw.wav'
# './drive/MyDrive/music_new_data/-cLzki-B06o.wav' -> './music_new_data/-cLzki-B06o.wav'
# './drive/MyDrive/music_new_data/ihJT65fZaHY.wav' -> './music_new_data/ihJT65fZaHY.wav'
# './drive/MyDrive/music_new_data/TWm_2QncYXg.wav' -> './music_new_data/TWm_2QncYXg.wav'
# './drive/MyDrive/music_new_data/itT0_RhSipQ.wav' -> './music_new_data/itT0_RhSipQ.wav'
# './drive/MyDrive/music_new_data/DGON0D8E17Q.wav' -> './music_new_data/DGON0D8E17Q.wav'
# './drive/MyDrive/music_new_data/ik-fXNjxw58.wav' -> './music_new_data/ik-fXNjxw58.wav'
# './drive/MyDrive/music_new_data/TWnrcjA6VTk.wav' -> './music_new_data/TWnrcjA6VTk.wav'
# './drive/MyDrive/music_new_data/DGbMEkQerYs.wav' -> './music_new_data/DGbMEkQerYs.wav'
# './drive/MyDrive/music_new_data/ikEuQPSBY-0.wav' -> './music_new_data/ikEuQPSBY-0.wav'
# './drive/MyDrive/music_new_data/-dVgUSrR8g4.wav' -> './music_new_data/-dVgUSrR8g4.wav'
# './drive/MyDrive/music_new_data/TX9PGFdqRak.wav' -> './music_new_data/TX9PGFdqRak.wav'
# './drive/MyDrive/music_new_data/ikJKSqnTylI.wav' -> './music_new_data/ikJKSqnTylI.wav'
# './drive/MyDrive/music_new_data/TZGDukKAVS8.wav' -> './music_new_data/TZGDukKAVS8.wav'
# './drive/MyDrive/music_new_data/imIFtW4O5S0.wav' -> './music_new_data/imIFtW4O5S0.wav'
# './drive/MyDrive/music_new_data/DGlP6oTqe5Y.wav' -> './music_new_data/DGlP6oTqe5Y.wav'
# './drive/MyDrive/music_new_data/-e4wXAy1iVo.wav' -> './music_new_data/-e4wXAy1iVo.wav'
# './drive/MyDrive/music_new_data/iqEQBCrOLWc.wav' -> './music_new_data/iqEQBCrOLWc.wav'
# './drive/MyDrive/music_new_data/TZlFTbvfKPE.wav' -> './music_new_data/TZlFTbvfKPE.wav'
# './drive/MyDrive/music_new_data/DLJGT99uEh4.wav' -> './music_new_data/DLJGT99uEh4.wav'
# './drive/MyDrive/music_new_data/iqOPJWWKo90.wav' -> './music_new_data/iqOPJWWKo90.wav'
# './drive/MyDrive/music_new_data/T_d82v2g93w.wav' -> './music_new_data/T_d82v2g93w.wav'
# './drive/MyDrive/music_new_data/DHDn79ee98Q.wav' -> './music_new_data/DHDn79ee98Q.wav'
# './drive/MyDrive/music_new_data/Ta0GmXPnGWk.wav' -> './music_new_data/Ta0GmXPnGWk.wav'
# './drive/MyDrive/music_new_data/TakkuFZJsis.wav' -> './music_new_data/TakkuFZJsis.wav'
# './drive/MyDrive/music_new_data/DHo1z0_ZUNA.wav' -> './music_new_data/DHo1z0_ZUNA.wav'
# './drive/MyDrive/music_new_data/TabaOeYq2ek.wav' -> './music_new_data/TabaOeYq2ek.wav'
# './drive/MyDrive/music_new_data/DJHEBMNPc-A.wav' -> './music_new_data/DJHEBMNPc-A.wav'
# './drive/MyDrive/music_new_data/-f1DNyngKVY.wav' -> './music_new_data/-f1DNyngKVY.wav'
# './drive/MyDrive/music_new_data/DKBbLySEGic.wav' -> './music_new_data/DKBbLySEGic.wav'
# './drive/MyDrive/music_new_data/TbA_TZn35LA.wav' -> './music_new_data/TbA_TZn35LA.wav'
# './drive/MyDrive/music_new_data/-eDAoheZrY8.wav' -> './music_new_data/-eDAoheZrY8.wav'
# './drive/MyDrive/music_new_data/TbYahEEj_B4.wav' -> './music_new_data/TbYahEEj_B4.wav'
# './drive/MyDrive/music_new_data/DKflAAykh6A.wav' -> './music_new_data/DKflAAykh6A.wav'
# './drive/MyDrive/music_new_data/TcJ7rdYMHiQ.wav' -> './music_new_data/TcJ7rdYMHiQ.wav'
# './drive/MyDrive/music_new_data/TdHdD1wxu_0.wav' -> './music_new_data/TdHdD1wxu_0.wav'
# './drive/MyDrive/music_new_data/itgeNVRhBKs.wav' -> './music_new_data/itgeNVRhBKs.wav'
# './drive/MyDrive/music_new_data/TcoRmHHHNgI.wav' -> './music_new_data/TcoRmHHHNgI.wav'
# './drive/MyDrive/music_new_data/TdvwUwpYYos.wav' -> './music_new_data/TdvwUwpYYos.wav'
# './drive/MyDrive/music_new_data/DLDZrtwyY_Y.wav' -> './music_new_data/DLDZrtwyY_Y.wav'
# './drive/MyDrive/music_new_data/Tfc6184uCIk.wav' -> './music_new_data/Tfc6184uCIk.wav'
# './drive/MyDrive/music_new_data/-f6s6kQEHFY.wav' -> './music_new_data/-f6s6kQEHFY.wav'
# './drive/MyDrive/music_new_data/TgCv5a22YUU.wav' -> './music_new_data/TgCv5a22YUU.wav'
# './drive/MyDrive/music_new_data/DNYDyXn6qso.wav' -> './music_new_data/DNYDyXn6qso.wav'
# './drive/MyDrive/music_new_data/ivymRS3iEZk.wav' -> './music_new_data/ivymRS3iEZk.wav'
# './drive/MyDrive/music_new_data/DMwvY--3XD0.wav' -> './music_new_data/DMwvY--3XD0.wav'
# './drive/MyDrive/music_new_data/-m5ZlWziIeA.wav' -> './music_new_data/-m5ZlWziIeA.wav'
# './drive/MyDrive/music_new_data/-fxh7jAJR8U.wav' -> './music_new_data/-fxh7jAJR8U.wav'
# './drive/MyDrive/music_new_data/DO8Db_i7IVc.wav' -> './music_new_data/DO8Db_i7IVc.wav'
# './drive/MyDrive/music_new_data/TgOr_C6xP6U.wav' -> './music_new_data/TgOr_C6xP6U.wav'
# './drive/MyDrive/music_new_data/-hSMzrWZCAE.wav' -> './music_new_data/-hSMzrWZCAE.wav'
# './drive/MyDrive/music_new_data/DOb8htND5_o.wav' -> './music_new_data/DOb8htND5_o.wav'
# './drive/MyDrive/music_new_data/Th6Tf6kA8RU.wav' -> './music_new_data/Th6Tf6kA8RU.wav'
# './drive/MyDrive/music_new_data/-hYRFCQdbLg.wav' -> './music_new_data/-hYRFCQdbLg.wav'
# './drive/MyDrive/music_new_data/TiDdR-6bIcY.wav' -> './music_new_data/TiDdR-6bIcY.wav'
# './drive/MyDrive/music_new_data/DP2vmsftZHY.wav' -> './music_new_data/DP2vmsftZHY.wav'
# './drive/MyDrive/music_new_data/-i9gpG3vPwA.wav' -> './music_new_data/-i9gpG3vPwA.wav'
# './drive/MyDrive/music_new_data/TiOBlG-R1Y4.wav' -> './music_new_data/TiOBlG-R1Y4.wav'
# './drive/MyDrive/music_new_data/izVCz3P43p8.wav' -> './music_new_data/izVCz3P43p8.wav'
# './drive/MyDrive/music_new_data/-i9uQMysy_A.wav' -> './music_new_data/-i9uQMysy_A.wav'
# './drive/MyDrive/music_new_data/DP72GDe6AAs.wav' -> './music_new_data/DP72GDe6AAs.wav'
# './drive/MyDrive/music_new_data/j-93krRXAaY.wav' -> './music_new_data/j-93krRXAaY.wav'
# './drive/MyDrive/music_new_data/DPW5M1FYxu4.wav' -> './music_new_data/DPW5M1FYxu4.wav'
# './drive/MyDrive/music_new_data/DQ_gcdLhAsY.wav' -> './music_new_data/DQ_gcdLhAsY.wav'
# './drive/MyDrive/music_new_data/-jpbCWcz2pk.wav' -> './music_new_data/-jpbCWcz2pk.wav'
# './drive/MyDrive/music_new_data/j0FynYzQvcM.wav' -> './music_new_data/j0FynYzQvcM.wav'
# './drive/MyDrive/music_new_data/j-TVVmVmygg.wav' -> './music_new_data/j-TVVmVmygg.wav'
# './drive/MyDrive/music_new_data/-kpR93atgd8.wav' -> './music_new_data/-kpR93atgd8.wav'
# './drive/MyDrive/music_new_data/-lPXTBXa0tE.wav' -> './music_new_data/-lPXTBXa0tE.wav'
# './drive/MyDrive/music_new_data/TkHZdMJPwKc.wav' -> './music_new_data/TkHZdMJPwKc.wav'
# './drive/MyDrive/music_new_data/j0UMI2DrnMA.wav' -> './music_new_data/j0UMI2DrnMA.wav'
# './drive/MyDrive/music_new_data/DQrdOgRb-oA.wav' -> './music_new_data/DQrdOgRb-oA.wav'
# './drive/MyDrive/music_new_data/TkclVqlyKx4.m4a.part' -> './music_new_data/TkclVqlyKx4.m4a.part'
# './drive/MyDrive/music_new_data/j3a60_lwWjE.wav' -> './music_new_data/j3a60_lwWjE.wav'
# './drive/MyDrive/music_new_data/DUNOn71oGCw.wav' -> './music_new_data/DUNOn71oGCw.wav'
# './drive/MyDrive/music_new_data/-m9pH0WXQto.wav' -> './music_new_data/-m9pH0WXQto.wav'
# './drive/MyDrive/music_new_data/DQzg3cZeYSw.wav' -> './music_new_data/DQzg3cZeYSw.wav'
# './drive/MyDrive/music_new_data/DRU-IFx-7yQ.wav' -> './music_new_data/DRU-IFx-7yQ.wav'
# './drive/MyDrive/music_new_data/-mB_XLq6g1g.wav' -> './music_new_data/-mB_XLq6g1g.wav'
# './drive/MyDrive/music_new_data/-mA_bqD1tgU.wav' -> './music_new_data/-mA_bqD1tgU.wav'
# './drive/MyDrive/music_new_data/DTkKGYCRMlc.wav' -> './music_new_data/DTkKGYCRMlc.wav'
# './drive/MyDrive/music_new_data/TnCXmm-v3Ys.wav' -> './music_new_data/TnCXmm-v3Ys.wav'
# './drive/MyDrive/music_new_data/DTnCrtCro44.wav' -> './music_new_data/DTnCrtCro44.wav'
# './drive/MyDrive/music_new_data/-nlkWWphiaM.wav' -> './music_new_data/-nlkWWphiaM.wav'
# './drive/MyDrive/music_new_data/DU3Vlaa8rU0.wav' -> './music_new_data/DU3Vlaa8rU0.wav'
# './drive/MyDrive/music_new_data/TnJE6W6Z6mM.wav' -> './music_new_data/TnJE6W6Z6mM.wav'
# './drive/MyDrive/music_new_data/j7AxC1RpjcE.wav' -> './music_new_data/j7AxC1RpjcE.wav'
# './drive/MyDrive/music_new_data/j3lH_Tevw5o.wav' -> './music_new_data/j3lH_Tevw5o.wav'
# './drive/MyDrive/music_new_data/DU5pD63Pv30.wav' -> './music_new_data/DU5pD63Pv30.wav'
# './drive/MyDrive/music_new_data/Tp8PG2xae8c.wav' -> './music_new_data/Tp8PG2xae8c.wav'
# './drive/MyDrive/music_new_data/j43Dwqzd8w8.wav' -> './music_new_data/j43Dwqzd8w8.wav'
# './drive/MyDrive/music_new_data/j5R0hwX27Gk.wav' -> './music_new_data/j5R0hwX27Gk.wav'
# './drive/MyDrive/music_new_data/TokHdpvX7Es.wav' -> './music_new_data/TokHdpvX7Es.wav'
# './drive/MyDrive/music_new_data/j4A1ObGurUk.wav' -> './music_new_data/j4A1ObGurUk.wav'
# './drive/MyDrive/music_new_data/DUmXpq-Cksg.wav' -> './music_new_data/DUmXpq-Cksg.wav'
# './drive/MyDrive/music_new_data/-o0ZtQIkM60.wav' -> './music_new_data/-o0ZtQIkM60.wav'
# './drive/MyDrive/music_new_data/TqIptTnXb20.wav' -> './music_new_data/TqIptTnXb20.wav'
# './drive/MyDrive/music_new_data/TqWmuwAYmnI.wav' -> './music_new_data/TqWmuwAYmnI.wav'
# './drive/MyDrive/music_new_data/DV5mynb77JM.wav' -> './music_new_data/DV5mynb77JM.wav'
# './drive/MyDrive/music_new_data/-oP-XX28B0s.wav' -> './music_new_data/-oP-XX28B0s.wav'
# './drive/MyDrive/music_new_data/TrvI6t4pAP0.wav' -> './music_new_data/TrvI6t4pAP0.wav'
# './drive/MyDrive/music_new_data/-pUfYFcsgG4.wav' -> './music_new_data/-pUfYFcsgG4.wav'
# './drive/MyDrive/music_new_data/DVuWm53IlVw.wav' -> './music_new_data/DVuWm53IlVw.wav'
# './drive/MyDrive/music_new_data/-qcTD2o6I9s.wav' -> './music_new_data/-qcTD2o6I9s.wav'
# './drive/MyDrive/music_new_data/Tt3BnoJw8ds.wav' -> './music_new_data/Tt3BnoJw8ds.wav'
# './drive/MyDrive/music_new_data/j6O_U9EseKQ.wav' -> './music_new_data/j6O_U9EseKQ.wav'
# './drive/MyDrive/music_new_data/j8z9a9A8LV4.wav' -> './music_new_data/j8z9a9A8LV4.wav'
# './drive/MyDrive/music_new_data/Ts04bBeY1d4.wav' -> './music_new_data/Ts04bBeY1d4.wav'
# './drive/MyDrive/music_new_data/-r2-9oyIzkQ.wav' -> './music_new_data/-r2-9oyIzkQ.wav'
# './drive/MyDrive/music_new_data/Ts3ZcUaELzA.wav' -> './music_new_data/Ts3ZcUaELzA.wav'
# './drive/MyDrive/music_new_data/-r7iz-9v9bA.wav' -> './music_new_data/-r7iz-9v9bA.wav'
# './drive/MyDrive/music_new_data/TsTdffJ9LHg.wav' -> './music_new_data/TsTdffJ9LHg.wav'
# './drive/MyDrive/music_new_data/-rAhS48FkYw.wav' -> './music_new_data/-rAhS48FkYw.wav'
# './drive/MyDrive/music_new_data/-sRFfU8k0Zs.wav' -> './music_new_data/-sRFfU8k0Zs.wav'
# './drive/MyDrive/music_new_data/Tsmx6Pb7CnU.wav' -> './music_new_data/Tsmx6Pb7CnU.wav'
# './drive/MyDrive/music_new_data/DW3z-ByrfWY.wav' -> './music_new_data/DW3z-ByrfWY.wav'
# './drive/MyDrive/music_new_data/j8FYy5YfK7k.wav' -> './music_new_data/j8FYy5YfK7k.wav'
# './drive/MyDrive/music_new_data/-sevczF5etI.wav' -> './music_new_data/-sevczF5etI.wav'
# './drive/MyDrive/music_new_data/-tKZOl4q1Kw.wav' -> './music_new_data/-tKZOl4q1Kw.wav'
# './drive/MyDrive/music_new_data/DW7Qe-50X_A.wav' -> './music_new_data/DW7Qe-50X_A.wav'
# './drive/MyDrive/music_new_data/Tvwi_YuLehk.wav' -> './music_new_data/Tvwi_YuLehk.wav'
# './drive/MyDrive/music_new_data/DX4_QlYLq30.wav' -> './music_new_data/DX4_QlYLq30.wav'
# './drive/MyDrive/music_new_data/-taO6N-rxv4.wav' -> './music_new_data/-taO6N-rxv4.wav'
# './drive/MyDrive/music_new_data/j9hAUlz5kQs.wav' -> './music_new_data/j9hAUlz5kQs.wav'
# './drive/MyDrive/music_new_data/DXd83S6NHLg.wav' -> './music_new_data/DXd83S6NHLg.wav'
# './drive/MyDrive/music_new_data/TworrkXAPuI.wav' -> './music_new_data/TworrkXAPuI.wav'
# './drive/MyDrive/music_new_data/j9UZv0GOJ_I.wav' -> './music_new_data/j9UZv0GOJ_I.wav'
# './drive/MyDrive/music_new_data/U-L9YCIdLbg.wav' -> './music_new_data/U-L9YCIdLbg.wav'
# './drive/MyDrive/music_new_data/DXeiJpZXVAI.wav' -> './music_new_data/DXeiJpZXVAI.wav'
# './drive/MyDrive/music_new_data/TyMZJqYmrwE.wav' -> './music_new_data/TyMZJqYmrwE.wav'
# './drive/MyDrive/music_new_data/DY7ko7iQCug.wav' -> './music_new_data/DY7ko7iQCug.wav'
# './drive/MyDrive/music_new_data/TzPuAqjoL80.wav' -> './music_new_data/TzPuAqjoL80.wav'
# './drive/MyDrive/music_new_data/DYp8940tHso.wav' -> './music_new_data/DYp8940tHso.wav'
# './drive/MyDrive/music_new_data/U-UF93NA3ko.wav' -> './music_new_data/U-UF93NA3ko.wav'
# './drive/MyDrive/music_new_data/DYpjbiyPUho.wav' -> './music_new_data/DYpjbiyPUho.wav'
# './drive/MyDrive/music_new_data/U0sjbOT6hY4.wav' -> './music_new_data/U0sjbOT6hY4.wav'
# './drive/MyDrive/music_new_data/DZ3EShJzOOc.wav' -> './music_new_data/DZ3EShJzOOc.wav'
# './drive/MyDrive/music_new_data/jD0nqkyuHPg.wav' -> './music_new_data/jD0nqkyuHPg.wav'
# './drive/MyDrive/music_new_data/-tmY1GEH3_Y.wav' -> './music_new_data/-tmY1GEH3_Y.wav'
# './drive/MyDrive/music_new_data/jFek2xLbEww.wav' -> './music_new_data/jFek2xLbEww.wav'
# './drive/MyDrive/music_new_data/U0xhbrULfNY.wav' -> './music_new_data/U0xhbrULfNY.wav'
# './drive/MyDrive/music_new_data/jBmP7xTI_TA.wav' -> './music_new_data/jBmP7xTI_TA.wav'
# './drive/MyDrive/music_new_data/U3TpCc2zHrI.wav' -> './music_new_data/U3TpCc2zHrI.wav'
# './drive/MyDrive/music_new_data/D_QEW1Lnl2Q.wav' -> './music_new_data/D_QEW1Lnl2Q.wav'
# './drive/MyDrive/music_new_data/U4MdEIQcZxs.wav' -> './music_new_data/U4MdEIQcZxs.wav'
# './drive/MyDrive/music_new_data/DdxW_JziHTA.wav' -> './music_new_data/DdxW_JziHTA.wav'
# './drive/MyDrive/music_new_data/U4UtZeTl2DE.wav' -> './music_new_data/U4UtZeTl2DE.wav'
# './drive/MyDrive/music_new_data/jHEBYrI8zHE.wav' -> './music_new_data/jHEBYrI8zHE.wav'
# './drive/MyDrive/music_new_data/-wymN80CiYU.wav' -> './music_new_data/-wymN80CiYU.wav'
# './drive/MyDrive/music_new_data/U6SYfguaJtk.wav' -> './music_new_data/U6SYfguaJtk.wav'
# './drive/MyDrive/music_new_data/D_usHKfOXCw.wav' -> './music_new_data/D_usHKfOXCw.wav'
# './drive/MyDrive/music_new_data/jIoDR_eskaU.wav' -> './music_new_data/jIoDR_eskaU.wav'
# './drive/MyDrive/music_new_data/U6aLiMIlqCc.wav' -> './music_new_data/U6aLiMIlqCc.wav'
# './drive/MyDrive/music_new_data/DaeJYtWgcoI.wav' -> './music_new_data/DaeJYtWgcoI.wav'
# './drive/MyDrive/music_new_data/U8XdDv5ERu4.wav' -> './music_new_data/U8XdDv5ERu4.wav'
# './drive/MyDrive/music_new_data/DaiVfxATCEE.wav' -> './music_new_data/DaiVfxATCEE.wav'
# './drive/MyDrive/music_new_data/U8yqYlErUz8.wav' -> './music_new_data/U8yqYlErUz8.wav'
# './drive/MyDrive/music_new_data/Db0c4aAwUbY.wav' -> './music_new_data/Db0c4aAwUbY.wav'
# './drive/MyDrive/music_new_data/-uaTK8sa5Ms.wav' -> './music_new_data/-uaTK8sa5Ms.wav'
# './drive/MyDrive/music_new_data/UBfHLeCBBsA.wav' -> './music_new_data/UBfHLeCBBsA.wav'
# './drive/MyDrive/music_new_data/UCBocxMCdck.wav' -> './music_new_data/UCBocxMCdck.wav'
# './drive/MyDrive/music_new_data/jKjj66pRXZA.wav' -> './music_new_data/jKjj66pRXZA.wav'
# './drive/MyDrive/music_new_data/jKWl63gozLE.wav' -> './music_new_data/jKWl63gozLE.wav'
# './drive/MyDrive/music_new_data/DewyiIpkzi8.wav' -> './music_new_data/DewyiIpkzi8.wav'
# './drive/MyDrive/music_new_data/Dg8BLvkzdr0.wav' -> './music_new_data/Dg8BLvkzdr0.wav'
# './drive/MyDrive/music_new_data/UC_XpUcIQ_8.wav' -> './music_new_data/UC_XpUcIQ_8.wav'
# './drive/MyDrive/music_new_data/jOkHEMsCCFc.wav' -> './music_new_data/jOkHEMsCCFc.wav'
# './drive/MyDrive/music_new_data/-v5hgCh3M2w.wav' -> './music_new_data/-v5hgCh3M2w.wav'
# './drive/MyDrive/music_new_data/DkZ1Or_D-g8.wav' -> './music_new_data/DkZ1Or_D-g8.wav'
# './drive/MyDrive/music_new_data/jR_wBfxgZwE.wav' -> './music_new_data/jR_wBfxgZwE.wav'
# './drive/MyDrive/music_new_data/DgVpK6r7JT4.wav' -> './music_new_data/DgVpK6r7JT4.wav'
# './drive/MyDrive/music_new_data/jP4M9V_Ka8k.wav' -> './music_new_data/jP4M9V_Ka8k.wav'
# './drive/MyDrive/music_new_data/DgqPgNqW2hE.wav' -> './music_new_data/DgqPgNqW2hE.wav'
# './drive/MyDrive/music_new_data/jPBg5cR8XeA.wav' -> './music_new_data/jPBg5cR8XeA.wav'
# './drive/MyDrive/music_new_data/DhnNZn8JjEQ.wav' -> './music_new_data/DhnNZn8JjEQ.wav'
# './drive/MyDrive/music_new_data/jPOWgfA0zAo.wav' -> './music_new_data/jPOWgfA0zAo.wav'
# './drive/MyDrive/music_new_data/Di7Rs4QmYKI.wav' -> './music_new_data/Di7Rs4QmYKI.wav'
# './drive/MyDrive/music_new_data/jPROsr_K710.wav' -> './music_new_data/jPROsr_K710.wav'
# './drive/MyDrive/music_new_data/Dk7ziLlNfeM.wav' -> './music_new_data/Dk7ziLlNfeM.wav'
# './drive/MyDrive/music_new_data/jQYSfy4DzIc.wav' -> './music_new_data/jQYSfy4DzIc.wav'
# './drive/MyDrive/music_new_data/-w12aSkQ9No.wav' -> './music_new_data/-w12aSkQ9No.wav'
# './drive/MyDrive/music_new_data/-zOybsEdM5E.wav' -> './music_new_data/-zOybsEdM5E.wav'
# './drive/MyDrive/music_new_data/-w4HLksto_k.wav' -> './music_new_data/-w4HLksto_k.wav'
# './drive/MyDrive/music_new_data/03frQGyrgQ4.wav' -> './music_new_data/03frQGyrgQ4.wav'
# './drive/MyDrive/music_new_data/-w8maIWtnUk.wav' -> './music_new_data/-w8maIWtnUk.wav'
# './drive/MyDrive/music_new_data/-wVWjl9Kq6U.wav' -> './music_new_data/-wVWjl9Kq6U.wav'
# './drive/MyDrive/music_new_data/UD0pisqyLKA.wav' -> './music_new_data/UD0pisqyLKA.wav'
# './drive/MyDrive/music_new_data/UDN11Q90Fa4.wav' -> './music_new_data/UDN11Q90Fa4.wav'
# './drive/MyDrive/music_new_data/jS9u6X6TQmk.wav' -> './music_new_data/jS9u6X6TQmk.wav'
# './drive/MyDrive/music_new_data/DlU56FGTVEk.wav' -> './music_new_data/DlU56FGTVEk.wav'
# './drive/MyDrive/music_new_data/UDS6PrY9ZIM.wav' -> './music_new_data/UDS6PrY9ZIM.wav'
# './drive/MyDrive/music_new_data/-zA6LL78KYU.wav' -> './music_new_data/-zA6LL78KYU.wav'
# './drive/MyDrive/music_new_data/jUJNETNCxh0.wav' -> './music_new_data/jUJNETNCxh0.wav'
# './drive/MyDrive/music_new_data/UDTsCTLkZzc.wav' -> './music_new_data/UDTsCTLkZzc.wav'
# './drive/MyDrive/music_new_data/DlVgHV1UobM.wav' -> './music_new_data/DlVgHV1UobM.wav'
# './drive/MyDrive/music_new_data/0-7PyzhzuYQ.wav' -> './music_new_data/0-7PyzhzuYQ.wav'
# './drive/MyDrive/music_new_data/UDg9vuBDtVU.wav' -> './music_new_data/UDg9vuBDtVU.wav'
# './drive/MyDrive/music_new_data/DpAfyjjQJyk.wav' -> './music_new_data/DpAfyjjQJyk.wav'
# './drive/MyDrive/music_new_data/DsAp3b1poeA.wav' -> './music_new_data/DsAp3b1poeA.wav'
# './drive/MyDrive/music_new_data/UEOUXjX5R2I.wav' -> './music_new_data/UEOUXjX5R2I.wav'
# './drive/MyDrive/music_new_data/DpS_TigOHWo.wav' -> './music_new_data/DpS_TigOHWo.wav'
# './drive/MyDrive/music_new_data/Dr4Ijx7Q9jk.wav' -> './music_new_data/Dr4Ijx7Q9jk.wav'
# './drive/MyDrive/music_new_data/DroAzooK4yw.wav' -> './music_new_data/DroAzooK4yw.wav'
# './drive/MyDrive/music_new_data/jV8kq0MpWMU.wav' -> './music_new_data/jV8kq0MpWMU.wav'
# './drive/MyDrive/music_new_data/00M9FhCet6s.wav' -> './music_new_data/00M9FhCet6s.wav'
# './drive/MyDrive/music_new_data/Du3Q6NdsSso.wav' -> './music_new_data/Du3Q6NdsSso.wav'
# './drive/MyDrive/music_new_data/UEel3wTf0Sk.wav' -> './music_new_data/UEel3wTf0Sk.wav'
# './drive/MyDrive/music_new_data/01PzcPKT3_E.wav' -> './music_new_data/01PzcPKT3_E.wav'
# './drive/MyDrive/music_new_data/jZi0VVWt72E.wav' -> './music_new_data/jZi0VVWt72E.wav'
# './drive/MyDrive/music_new_data/UFyOGqmITjM.wav' -> './music_new_data/UFyOGqmITjM.wav'
# './drive/MyDrive/music_new_data/01hjVJN9xCg.wav' -> './music_new_data/01hjVJN9xCg.wav'
# './drive/MyDrive/music_new_data/0298WjE3_tk.wav' -> './music_new_data/0298WjE3_tk.wav'
# './drive/MyDrive/music_new_data/jWQu301CEp8.wav' -> './music_new_data/jWQu301CEp8.wav'
# './drive/MyDrive/music_new_data/02Qntw26enM.wav' -> './music_new_data/02Qntw26enM.wav'
# './drive/MyDrive/music_new_data/jWTm17KZGI8.wav' -> './music_new_data/jWTm17KZGI8.wav'
# './drive/MyDrive/music_new_data/DueNcVFHI0k.wav' -> './music_new_data/DueNcVFHI0k.wav'
# './drive/MyDrive/music_new_data/jXi1dFAB0n8.wav' -> './music_new_data/jXi1dFAB0n8.wav'
# './drive/MyDrive/music_new_data/UGEqY_NTMpI.wav' -> './music_new_data/UGEqY_NTMpI.wav'
# './drive/MyDrive/music_new_data/03z0rpIkm5g.wav' -> './music_new_data/03z0rpIkm5g.wav'
# './drive/MyDrive/music_new_data/04NjXsLyCl4.wav' -> './music_new_data/04NjXsLyCl4.wav'
# './drive/MyDrive/music_new_data/UHvYrO1IGCc.wav' -> './music_new_data/UHvYrO1IGCc.wav'
# './drive/MyDrive/music_new_data/05JAmKFVy44.wav' -> './music_new_data/05JAmKFVy44.wav'
# './drive/MyDrive/music_new_data/jZkHpNnXLB0.wav' -> './music_new_data/jZkHpNnXLB0.wav'
# './drive/MyDrive/music_new_data/Dv21JlCT4_k.wav' -> './music_new_data/Dv21JlCT4_k.wav'
# './drive/MyDrive/music_new_data/jaJdPUAv6N0.wav' -> './music_new_data/jaJdPUAv6N0.wav'
# './drive/MyDrive/music_new_data/UIOnnpaqBy8.wav' -> './music_new_data/UIOnnpaqBy8.wav'
# './drive/MyDrive/music_new_data/DvN5813H7Bo.wav' -> './music_new_data/DvN5813H7Bo.wav'
# './drive/MyDrive/music_new_data/E16FgDFQI_w.wav' -> './music_new_data/E16FgDFQI_w.wav'
# './drive/MyDrive/music_new_data/UJA5AWbt6HM.wav' -> './music_new_data/UJA5AWbt6HM.wav'
# './drive/MyDrive/music_new_data/jcZQhxb5lyw.wav' -> './music_new_data/jcZQhxb5lyw.wav'
# './drive/MyDrive/music_new_data/UJAk1nNdo1I.wav' -> './music_new_data/UJAk1nNdo1I.wav'
# './drive/MyDrive/music_new_data/jbe3VM-5xdc.wav' -> './music_new_data/jbe3VM-5xdc.wav'
# './drive/MyDrive/music_new_data/DvOA0K-DIFM.wav' -> './music_new_data/DvOA0K-DIFM.wav'
# './drive/MyDrive/music_new_data/Dx58W7opw5A.wav' -> './music_new_data/Dx58W7opw5A.wav'
# './drive/MyDrive/music_new_data/ULHPhjaJ6p0.wav' -> './music_new_data/ULHPhjaJ6p0.wav'
# './drive/MyDrive/music_new_data/jbyVJdDlo2Q.wav' -> './music_new_data/jbyVJdDlo2Q.wav'
# './drive/MyDrive/music_new_data/DyPmDDN8m78.wav' -> './music_new_data/DyPmDDN8m78.wav'
# './drive/MyDrive/music_new_data/ULXbXpLcoVA.wav' -> './music_new_data/ULXbXpLcoVA.wav'
# './drive/MyDrive/music_new_data/05OJDYeHLMc.wav' -> './music_new_data/05OJDYeHLMc.wav'
# './drive/MyDrive/music_new_data/DysXetu2I0E.wav' -> './music_new_data/DysXetu2I0E.wav'
# './drive/MyDrive/music_new_data/jd1IS7N3u0I.wav' -> './music_new_data/jd1IS7N3u0I.wav'
# './drive/MyDrive/music_new_data/UNJswfXKJ3s.wav' -> './music_new_data/UNJswfXKJ3s.wav'
# './drive/MyDrive/music_new_data/06Brdf83RZE.wav' -> './music_new_data/06Brdf83RZE.wav'
# './drive/MyDrive/music_new_data/E29kpquu8W4.wav' -> './music_new_data/E29kpquu8W4.wav'
# './drive/MyDrive/music_new_data/jd94Ox7KJ9Q.wav' -> './music_new_data/jd94Ox7KJ9Q.wav'
# './drive/MyDrive/music_new_data/06IU9WsEp3s.wav' -> './music_new_data/06IU9WsEp3s.wav'
# './drive/MyDrive/music_new_data/UO9HtZMrbBE.wav' -> './music_new_data/UO9HtZMrbBE.wav'
# './drive/MyDrive/music_new_data/UOAv5b6MGxw.wav' -> './music_new_data/UOAv5b6MGxw.wav'
# './drive/MyDrive/music_new_data/07-3grCQ8EU.wav' -> './music_new_data/07-3grCQ8EU.wav'
# './drive/MyDrive/music_new_data/jdEbwMS9xqo.wav' -> './music_new_data/jdEbwMS9xqo.wav'
# './drive/MyDrive/music_new_data/07xGXxIHOL4.wav' -> './music_new_data/07xGXxIHOL4.wav'
# './drive/MyDrive/music_new_data/E2gstPe3Im4.wav' -> './music_new_data/E2gstPe3Im4.wav'
# './drive/MyDrive/music_new_data/je1amtXOKF4.wav' -> './music_new_data/je1amtXOKF4.wav'
# './drive/MyDrive/music_new_data/UOC4VWQpnDM.wav' -> './music_new_data/UOC4VWQpnDM.wav'
# './drive/MyDrive/music_new_data/07-vpXo91XM.wav' -> './music_new_data/07-vpXo91XM.wav'
# './drive/MyDrive/music_new_data/E2v025Ilsqo.wav' -> './music_new_data/E2v025Ilsqo.wav'
# './drive/MyDrive/music_new_data/je96vkMY60c.wav' -> './music_new_data/je96vkMY60c.wav'
# './drive/MyDrive/music_new_data/07FxCXxknY4.wav' -> './music_new_data/07FxCXxknY4.wav'
# './drive/MyDrive/music_new_data/UOKWQ2EHJQI.wav' -> './music_new_data/UOKWQ2EHJQI.wav'
# './drive/MyDrive/music_new_data/E3F9bzeCgTQ.wav' -> './music_new_data/E3F9bzeCgTQ.wav'
# './drive/MyDrive/music_new_data/jfxTOlXF3Kk.wav' -> './music_new_data/jfxTOlXF3Kk.wav'
# './drive/MyDrive/music_new_data/07mS0mSTDjY.wav' -> './music_new_data/07mS0mSTDjY.wav'
# './drive/MyDrive/music_new_data/UPPHkyd7lwE.wav' -> './music_new_data/UPPHkyd7lwE.wav'
# './drive/MyDrive/music_new_data/jhQpTVVUQ9E.wav' -> './music_new_data/jhQpTVVUQ9E.wav'
# ...
# './drive/MyDrive/music_new_data/Fg8yzA7zifw.wav' -> './music_new_data/Fg8yzA7zifw.wav'
# './drive/MyDrive/music_new_data/VzHL56yq8bI.wav' -> './music_new_data/VzHL56yq8bI.wav'
# './drive/MyDrive/music_new_data/VzGHr0aV220.wav' -> './music_new_data/VzGHr0aV220.wav'
# './drive/MyDrive/music_new_data/FgUSmmTEE3M.wav' -> './music_new_data/FgUSmmTEE3M.wav'
# './drive/MyDrive/music_new_data/19Pp9QEw17U.wav' -> './music_new_data/19Pp9QEw17U.wav'
# './drive/MyDrive/music_new_data/17AtKbQ7glU.wav' -> './music_new_data/17AtKbQ7glU.wav'
# './drive/MyDrive/music_new_data/VzYc-c-uHjI.wav' -> './music_new_data/VzYc-c-uHjI.wav'
# './drive/MyDrive/music_new_data/W-nkxlYTdV4.wav' -> './music_new_data/W-nkxlYTdV4.wav'
# './drive/MyDrive/music_new_data/W00eTCOgUNs.wav' -> './music_new_data/W00eTCOgUNs.wav'
# './drive/MyDrive/music_new_data/lPFsijo8xYs.wav' -> './music_new_data/lPFsijo8xYs.wav'
# './drive/MyDrive/music_new_data/19-GI2LzOtc.wav' -> './music_new_data/19-GI2LzOtc.wav'
# './drive/MyDrive/music_new_data/lR8am4rK7qQ.wav' -> './music_new_data/lR8am4rK7qQ.wav'
# './drive/MyDrive/music_new_data/Fsm-xDmyFKg.wav' -> './music_new_data/Fsm-xDmyFKg.wav'
# './drive/MyDrive/music_new_data/lRC2lurjPBw.wav' -> './music_new_data/lRC2lurjPBw.wav'
# './drive/MyDrive/music_new_data/Fh53p0Tnnxg.wav' -> './music_new_data/Fh53p0Tnnxg.wav'
# './drive/MyDrive/music_new_data/W2EJai-3k2w.wav' -> './music_new_data/W2EJai-3k2w.wav'
# './drive/MyDrive/music_new_data/lRTeWmoeen4.wav' -> './music_new_data/lRTeWmoeen4.wav'
# './drive/MyDrive/music_new_data/1ACn3u5UnBw.wav' -> './music_new_data/1ACn3u5UnBw.wav'
# './drive/MyDrive/music_new_data/FiKY19GK6-8.wav' -> './music_new_data/FiKY19GK6-8.wav'
# './drive/MyDrive/music_new_data/1Ccis4FDGwY.wav' -> './music_new_data/1Ccis4FDGwY.wav'
# './drive/MyDrive/music_new_data/lSb7Y-_3to8.wav' -> './music_new_data/lSb7Y-_3to8.wav'
# './drive/MyDrive/music_new_data/1AOe82obwcY.wav' -> './music_new_data/1AOe82obwcY.wav'
# './drive/MyDrive/music_new_data/FkpJaXzgMBQ.wav' -> './music_new_data/FkpJaXzgMBQ.wav'
# './drive/MyDrive/music_new_data/lSbCqHZy_l4.wav' -> './music_new_data/lSbCqHZy_l4.wav'
# './drive/MyDrive/music_new_data/1ArUx6UCxe4.wav' -> './music_new_data/1ArUx6UCxe4.wav'
# './drive/MyDrive/music_new_data/Fm6ss1PBC1Q.wav' -> './music_new_data/Fm6ss1PBC1Q.wav'
# './drive/MyDrive/music_new_data/1BVSYfNCcv0.wav' -> './music_new_data/1BVSYfNCcv0.wav'
# './drive/MyDrive/music_new_data/lTAfSpsyTSI.wav' -> './music_new_data/lTAfSpsyTSI.wav'
# './drive/MyDrive/music_new_data/W2KaBnoGxek.wav' -> './music_new_data/W2KaBnoGxek.wav'
# './drive/MyDrive/music_new_data/FmytwY7SAfU.wav' -> './music_new_data/FmytwY7SAfU.wav'
# './drive/MyDrive/music_new_data/FoFMRXlNJ6Y.wav' -> './music_new_data/FoFMRXlNJ6Y.wav'
# './drive/MyDrive/music_new_data/W2nlA65AwtU.wav' -> './music_new_data/W2nlA65AwtU.wav'
# './drive/MyDrive/music_new_data/FsCQmTluSDw.wav' -> './music_new_data/FsCQmTluSDw.wav'
# './drive/MyDrive/music_new_data/1DNoynuGLV4.wav' -> './music_new_data/1DNoynuGLV4.wav'
# './drive/MyDrive/music_new_data/W3DwueAy65k.wav' -> './music_new_data/W3DwueAy65k.wav'
# './drive/MyDrive/music_new_data/1FnA3w94zXI.wav' -> './music_new_data/1FnA3w94zXI.wav'
# './drive/MyDrive/music_new_data/1FU5odlgLmo.wav' -> './music_new_data/1FU5odlgLmo.wav'
# './drive/MyDrive/music_new_data/W3lKc2hj4XU.wav' -> './music_new_data/W3lKc2hj4XU.wav'
# './drive/MyDrive/music_new_data/FscE_AHEmFk.wav' -> './music_new_data/FscE_AHEmFk.wav'
# './drive/MyDrive/music_new_data/lTLsL94ABRs.wav' -> './music_new_data/lTLsL94ABRs.wav'
# './drive/MyDrive/music_new_data/W4eLgBYEEqA.wav' -> './music_new_data/W4eLgBYEEqA.wav'
# './drive/MyDrive/music_new_data/1FnT0RrfMEA.wav' -> './music_new_data/1FnT0RrfMEA.wav'
# './drive/MyDrive/music_new_data/Fsv_syCvzsc.wav' -> './music_new_data/Fsv_syCvzsc.wav'
# './drive/MyDrive/music_new_data/W4nQpOHIPEw.wav' -> './music_new_data/W4nQpOHIPEw.wav'
# './drive/MyDrive/music_new_data/FsnRM2irjvI.wav' -> './music_new_data/FsnRM2irjvI.wav'
# './drive/MyDrive/music_new_data/1GCOnj53QYM.wav' -> './music_new_data/1GCOnj53QYM.wav'
# './drive/MyDrive/music_new_data/lTOzGIOIfq0.wav' -> './music_new_data/lTOzGIOIfq0.wav'
# './drive/MyDrive/music_new_data/W58kioYp1Ms.wav' -> './music_new_data/W58kioYp1Ms.wav'
# './drive/MyDrive/music_new_data/FteW_2gNtD4.wav' -> './music_new_data/FteW_2gNtD4.wav'
# './drive/MyDrive/music_new_data/1IK4OeOqAEo.wav' -> './music_new_data/1IK4OeOqAEo.wav'
# './drive/MyDrive/music_new_data/lTuEsrVV6Uw.wav' -> './music_new_data/lTuEsrVV6Uw.wav'
# './drive/MyDrive/music_new_data/W5BB6pubJZI.wav' -> './music_new_data/W5BB6pubJZI.wav'
# './drive/MyDrive/music_new_data/1ILLsA6gqHE.wav' -> './music_new_data/1ILLsA6gqHE.wav'
# './drive/MyDrive/music_new_data/FvdUm5j_oA0.wav' -> './music_new_data/FvdUm5j_oA0.wav'
# './drive/MyDrive/music_new_data/lUp9WnLYetg.wav' -> './music_new_data/lUp9WnLYetg.wav'
# './drive/MyDrive/music_new_data/W5eOW25vvbw.wav' -> './music_new_data/W5eOW25vvbw.wav'
# './drive/MyDrive/music_new_data/1IMi7yfZVVM.wav' -> './music_new_data/1IMi7yfZVVM.wav'
# './drive/MyDrive/music_new_data/FtskdD6Py7Y.wav' -> './music_new_data/FtskdD6Py7Y.wav'
# './drive/MyDrive/music_new_data/lV0-LMVpZLg.wav' -> './music_new_data/lV0-LMVpZLg.wav'
# './drive/MyDrive/music_new_data/W5t-T1vP2DU.wav' -> './music_new_data/W5t-T1vP2DU.wav'
# './drive/MyDrive/music_new_data/1Is1xfDjZrw.wav' -> './music_new_data/1Is1xfDjZrw.wav'
# './drive/MyDrive/music_new_data/FvIKye4-iGc.wav' -> './music_new_data/FvIKye4-iGc.wav'
# './drive/MyDrive/music_new_data/Fv9swdLA-lo.wav' -> './music_new_data/Fv9swdLA-lo.wav'
# './drive/MyDrive/music_new_data/lXrypwLQO3U.wav' -> './music_new_data/lXrypwLQO3U.wav'
# './drive/MyDrive/music_new_data/1JpeDWbgUO8.wav' -> './music_new_data/1JpeDWbgUO8.wav'
# './drive/MyDrive/music_new_data/FvQgVl5IBHw.wav' -> './music_new_data/FvQgVl5IBHw.wav'
# './drive/MyDrive/music_new_data/1JqNiV03kog.wav' -> './music_new_data/1JqNiV03kog.wav'
# './drive/MyDrive/music_new_data/lYJAqOpp6RM.wav' -> './music_new_data/lYJAqOpp6RM.wav'
# './drive/MyDrive/music_new_data/lYtoy8sa-Q0.wav' -> './music_new_data/lYtoy8sa-Q0.wav'
# './drive/MyDrive/music_new_data/1KmsVHx7E2c.wav' -> './music_new_data/1KmsVHx7E2c.wav'
# './drive/MyDrive/music_new_data/1JwoLPCIGhs.wav' -> './music_new_data/1JwoLPCIGhs.wav'
# './drive/MyDrive/music_new_data/lZavPVn7O4Q.wav' -> './music_new_data/lZavPVn7O4Q.wav'
# './drive/MyDrive/music_new_data/FxeA9blzUD8.wav' -> './music_new_data/FxeA9blzUD8.wav'
# './drive/MyDrive/music_new_data/W7KbboEOmeM.wav' -> './music_new_data/W7KbboEOmeM.wav'
# './drive/MyDrive/music_new_data/1KN3GrwhY8c.wav' -> './music_new_data/1KN3GrwhY8c.wav'
# './drive/MyDrive/music_new_data/FxpV97ILuSo.wav' -> './music_new_data/FxpV97ILuSo.wav'
# './drive/MyDrive/music_new_data/laVgKAcv8XA.wav' -> './music_new_data/laVgKAcv8XA.wav'
# './drive/MyDrive/music_new_data/W7U-glgu4GM.wav' -> './music_new_data/W7U-glgu4GM.wav'
# './drive/MyDrive/music_new_data/lbB2VQYIMo0.wav' -> './music_new_data/lbB2VQYIMo0.wav'
# './drive/MyDrive/music_new_data/1LA64TXatWk.wav' -> './music_new_data/1LA64TXatWk.wav'
# './drive/MyDrive/music_new_data/1OIfQHKnAcw.wav' -> './music_new_data/1OIfQHKnAcw.wav'
# './drive/MyDrive/music_new_data/leiPemYDg-8.wav' -> './music_new_data/leiPemYDg-8.wav'
# './drive/MyDrive/music_new_data/W7i4LkdSfjw.wav' -> './music_new_data/W7i4LkdSfjw.wav'
# './drive/MyDrive/music_new_data/1MwaXCfUvX8.wav' -> './music_new_data/1MwaXCfUvX8.wav'
# './drive/MyDrive/music_new_data/lePP2BaZhJU.wav' -> './music_new_data/lePP2BaZhJU.wav'
# './drive/MyDrive/music_new_data/W85w938G5ZM.wav' -> './music_new_data/W85w938G5ZM.wav'
# './drive/MyDrive/music_new_data/Fy51z2RwH3E.wav' -> './music_new_data/Fy51z2RwH3E.wav'
# './drive/MyDrive/music_new_data/W8Xv3Q2kGRA.wav' -> './music_new_data/W8Xv3Q2kGRA.wav'
# './drive/MyDrive/music_new_data/1O4LpU7HggY.wav' -> './music_new_data/1O4LpU7HggY.wav'
# './drive/MyDrive/music_new_data/Fz-ZNyVKWro.wav' -> './music_new_data/Fz-ZNyVKWro.wav'
# './drive/MyDrive/music_new_data/WBBKiXYVEdM.wav' -> './music_new_data/WBBKiXYVEdM.wav'
# './drive/MyDrive/music_new_data/WAxDN-FyPn8.wav' -> './music_new_data/WAxDN-FyPn8.wav'
# './drive/MyDrive/music_new_data/lfCWGQ6URds.wav' -> './music_new_data/lfCWGQ6URds.wav'
# './drive/MyDrive/music_new_data/lh6ACdwNlyk.wav' -> './music_new_data/lh6ACdwNlyk.wav'
# './drive/MyDrive/music_new_data/FzG8ZQAhKrE.wav' -> './music_new_data/FzG8ZQAhKrE.wav'
# './drive/MyDrive/music_new_data/1PKxdTlquCA.wav' -> './music_new_data/1PKxdTlquCA.wav'
# './drive/MyDrive/music_new_data/WCiS9IDILQg.wav' -> './music_new_data/WCiS9IDILQg.wav'
# './drive/MyDrive/music_new_data/G-5UYGccne4.wav' -> './music_new_data/G-5UYGccne4.wav'
# './drive/MyDrive/music_new_data/liagR7x12O4.wav' -> './music_new_data/liagR7x12O4.wav'
# './drive/MyDrive/music_new_data/lhizlCmlbYY.wav' -> './music_new_data/lhizlCmlbYY.wav'
# './drive/MyDrive/music_new_data/1PN-bfs2EhY.wav' -> './music_new_data/1PN-bfs2EhY.wav'
# './drive/MyDrive/music_new_data/WCifI6rwOoM.wav' -> './music_new_data/WCifI6rwOoM.wav'
# './drive/MyDrive/music_new_data/G-7BfzMgZL8.wav' -> './music_new_data/G-7BfzMgZL8.wav'
# './drive/MyDrive/music_new_data/1PSzSTilu_s.wav' -> './music_new_data/1PSzSTilu_s.wav'
# './drive/MyDrive/music_new_data/1Q9DXhXMSFI.wav' -> './music_new_data/1Q9DXhXMSFI.wav'
# './drive/MyDrive/music_new_data/WCl93HBuj60.wav' -> './music_new_data/WCl93HBuj60.wav'
# './drive/MyDrive/music_new_data/G13NEVAm6-o.wav' -> './music_new_data/G13NEVAm6-o.wav'
# './drive/MyDrive/music_new_data/1RRGInmOhTQ.wav' -> './music_new_data/1RRGInmOhTQ.wav'
# './drive/MyDrive/music_new_data/liuCTk2nPG8.wav' -> './music_new_data/liuCTk2nPG8.wav'
# './drive/MyDrive/music_new_data/WE0JqjuhaQI.wav' -> './music_new_data/WE0JqjuhaQI.wav'
# './drive/MyDrive/music_new_data/1QFli7KSXAQ.wav' -> './music_new_data/1QFli7KSXAQ.wav'
# './drive/MyDrive/music_new_data/WEVBqGarEIY.wav' -> './music_new_data/WEVBqGarEIY.wav'
# './drive/MyDrive/music_new_data/lmrzR9cSMRY.wav' -> './music_new_data/lmrzR9cSMRY.wav'
# './drive/MyDrive/music_new_data/G18Nt0ZeEJQ.wav' -> './music_new_data/G18Nt0ZeEJQ.wav'
# './drive/MyDrive/music_new_data/1QSD-dzEv7Y.wav' -> './music_new_data/1QSD-dzEv7Y.wav'
# './drive/MyDrive/music_new_data/G22YfD5xxMU.wav' -> './music_new_data/G22YfD5xxMU.wav'
# './drive/MyDrive/music_new_data/lnJdWXRgjKo.wav' -> './music_new_data/lnJdWXRgjKo.wav'
# './drive/MyDrive/music_new_data/G2JDDwIuNrQ.wav' -> './music_new_data/G2JDDwIuNrQ.wav'
# './drive/MyDrive/music_new_data/WEXJSNm_T0o.wav' -> './music_new_data/WEXJSNm_T0o.wav'
# './drive/MyDrive/music_new_data/WIuLaxWIAAI.wav' -> './music_new_data/WIuLaxWIAAI.wav'
# './drive/MyDrive/music_new_data/lnYOC9tKUBs.wav' -> './music_new_data/lnYOC9tKUBs.wav'
# './drive/MyDrive/music_new_data/lnnlghshsVo.wav' -> './music_new_data/lnnlghshsVo.wav'
# './drive/MyDrive/music_new_data/WFPGA_BYkKU.wav' -> './music_new_data/WFPGA_BYkKU.wav'
# './drive/MyDrive/music_new_data/1Rd1w7Ty1ak.wav' -> './music_new_data/1Rd1w7Ty1ak.wav'
# './drive/MyDrive/music_new_data/G2uCAwYS6w0.wav' -> './music_new_data/G2uCAwYS6w0.wav'
# './drive/MyDrive/music_new_data/G4fTKotMoWI.wav' -> './music_new_data/G4fTKotMoWI.wav'
# './drive/MyDrive/music_new_data/WI2d5vDJeLo.wav' -> './music_new_data/WI2d5vDJeLo.wav'
# './drive/MyDrive/music_new_data/1RhYdQnZ_hw.wav' -> './music_new_data/1RhYdQnZ_hw.wav'
# './drive/MyDrive/music_new_data/1RwhRTe-OKk.wav' -> './music_new_data/1RwhRTe-OKk.wav'
# './drive/MyDrive/music_new_data/1SO5RJLWKAs.wav' -> './music_new_data/1SO5RJLWKAs.wav'
# './drive/MyDrive/music_new_data/WIVu5PapmX4.wav' -> './music_new_data/WIVu5PapmX4.wav'
# './drive/MyDrive/music_new_data/WJIrkvEq4EI.wav' -> './music_new_data/WJIrkvEq4EI.wav'
# './drive/MyDrive/music_new_data/G6A9NKeK8ko.wav' -> './music_new_data/G6A9NKeK8ko.wav'
# './drive/MyDrive/music_new_data/WJORWlj6BW8.wav' -> './music_new_data/WJORWlj6BW8.wav'
# './drive/MyDrive/music_new_data/loyHHBilYPM.wav' -> './music_new_data/loyHHBilYPM.wav'
# './drive/MyDrive/music_new_data/1TyOPtg0Yfk.wav' -> './music_new_data/1TyOPtg0Yfk.wav'
# './drive/MyDrive/music_new_data/G6ihF82lvEA.wav' -> './music_new_data/G6ihF82lvEA.wav'
# './drive/MyDrive/music_new_data/1SqihV_DnEg.wav' -> './music_new_data/1SqihV_DnEg.wav'
# './drive/MyDrive/music_new_data/lpHa-S_x1LA.wav' -> './music_new_data/lpHa-S_x1LA.wav'
# './drive/MyDrive/music_new_data/WKYUiLace9Y.wav' -> './music_new_data/WKYUiLace9Y.wav'
# './drive/MyDrive/music_new_data/1ToIyrmWFjw.wav' -> './music_new_data/1ToIyrmWFjw.wav'
# './drive/MyDrive/music_new_data/WK-gdfCurCg.wav' -> './music_new_data/WK-gdfCurCg.wav'
# './drive/MyDrive/music_new_data/lqCx0HgF1ZM.wav' -> './music_new_data/lqCx0HgF1ZM.wav'
# './drive/MyDrive/music_new_data/WKL40jfQD3g.wav' -> './music_new_data/WKL40jfQD3g.wav'
# './drive/MyDrive/music_new_data/G7pD1K3jYg4.wav' -> './music_new_data/G7pD1K3jYg4.wav'
# './drive/MyDrive/music_new_data/lqeAf-DqE3I.wav' -> './music_new_data/lqeAf-DqE3I.wav'
# './drive/MyDrive/music_new_data/1V7ReAk9k-4.wav' -> './music_new_data/1V7ReAk9k-4.wav'
# './drive/MyDrive/music_new_data/1VKSpjXZvKo.wav' -> './music_new_data/1VKSpjXZvKo.wav'
# './drive/MyDrive/music_new_data/lvktro0asjs.wav' -> './music_new_data/lvktro0asjs.wav'
# './drive/MyDrive/music_new_data/1W2Cz2Jj76Q.wav' -> './music_new_data/1W2Cz2Jj76Q.wav'
# './drive/MyDrive/music_new_data/G8iTuTi8ywU.wav' -> './music_new_data/G8iTuTi8ywU.wav'
# './drive/MyDrive/music_new_data/1W2FOzSXsxs.wav' -> './music_new_data/1W2FOzSXsxs.wav'
# './drive/MyDrive/music_new_data/ltZCJ7aPtO0.wav' -> './music_new_data/ltZCJ7aPtO0.wav'
# './drive/MyDrive/music_new_data/G9gsCU85c8k.wav' -> './music_new_data/G9gsCU85c8k.wav'
# './drive/MyDrive/music_new_data/1WlvXneu6oY.wav' -> './music_new_data/1WlvXneu6oY.wav'
# './drive/MyDrive/music_new_data/WMtztIW1f6k.wav' -> './music_new_data/WMtztIW1f6k.wav'
# './drive/MyDrive/music_new_data/GAoGADilmV8.wav' -> './music_new_data/GAoGADilmV8.wav'
# './drive/MyDrive/music_new_data/ltysCJWnvsI.wav' -> './music_new_data/ltysCJWnvsI.wav'
# './drive/MyDrive/music_new_data/GBLKj2d0iC4.wav' -> './music_new_data/GBLKj2d0iC4.wav'
# './drive/MyDrive/music_new_data/GAohd8KvONo.wav' -> './music_new_data/GAohd8KvONo.wav'
# './drive/MyDrive/music_new_data/1Xtkou9dtyA.wav' -> './music_new_data/1Xtkou9dtyA.wav'
# './drive/MyDrive/music_new_data/WNmAlKrAPjQ.wav' -> './music_new_data/WNmAlKrAPjQ.wav'
# './drive/MyDrive/music_new_data/GBMlv6j0WJ8.wav' -> './music_new_data/GBMlv6j0WJ8.wav'
# './drive/MyDrive/music_new_data/1YPYQP6yupA.wav' -> './music_new_data/1YPYQP6yupA.wav'
# './drive/MyDrive/music_new_data/lwQVcLxFBIQ.wav' -> './music_new_data/lwQVcLxFBIQ.wav'
# './drive/MyDrive/music_new_data/WNv-YNn1cZ8.wav' -> './music_new_data/WNv-YNn1cZ8.wav'
# './drive/MyDrive/music_new_data/1ZaxqZMs21M.wav' -> './music_new_data/1ZaxqZMs21M.wav'
# './drive/MyDrive/music_new_data/lwdDm3UO5WM.wav' -> './music_new_data/lwdDm3UO5WM.wav'
# './drive/MyDrive/music_new_data/GFT6TeQx_0U.wav' -> './music_new_data/GFT6TeQx_0U.wav'
# './drive/MyDrive/music_new_data/WO_Y7djT2k4.wav' -> './music_new_data/WO_Y7djT2k4.wav'
# './drive/MyDrive/music_new_data/lymmNwQA0WA.wav' -> './music_new_data/lymmNwQA0WA.wav'
# './drive/MyDrive/music_new_data/GBsate-JQAo.wav' -> './music_new_data/GBsate-JQAo.wav'
# './drive/MyDrive/music_new_data/1Ziku4FLka4.wav' -> './music_new_data/1Ziku4FLka4.wav'
# './drive/MyDrive/music_new_data/WPguqXCBQCI.wav' -> './music_new_data/WPguqXCBQCI.wav'
# './drive/MyDrive/music_new_data/m--xEFqqrLc.wav' -> './music_new_data/m--xEFqqrLc.wav'
# './drive/MyDrive/music_new_data/1_YHHL_t2GI.wav' -> './music_new_data/1_YHHL_t2GI.wav'
# './drive/MyDrive/music_new_data/GF8QWSW0UbY.wav' -> './music_new_data/GF8QWSW0UbY.wav'
# './drive/MyDrive/music_new_data/WQsuFvw43RA.wav' -> './music_new_data/WQsuFvw43RA.wav'
# './drive/MyDrive/music_new_data/1bSP4wLfMpA.wav' -> './music_new_data/1bSP4wLfMpA.wav'
# './drive/MyDrive/music_new_data/1a_nvi4sW64.wav' -> './music_new_data/1a_nvi4sW64.wav'
# './drive/MyDrive/music_new_data/m-NM_tIWjxs.wav' -> './music_new_data/m-NM_tIWjxs.wav'
# './drive/MyDrive/music_new_data/GFGwPa9d9XQ.wav' -> './music_new_data/GFGwPa9d9XQ.wav'
# './drive/MyDrive/music_new_data/1cqcTbDxsHM.wav' -> './music_new_data/1cqcTbDxsHM.wav'

# %% [markdown]
# Interesting! Let's see what we have
# * The `audio` key maps to a dictionary that contains both the audio (`.wav`) file and the `numpy` array of the data already loaded, as well as the sampling rate
# * `is_audioset_eval` specifies if it's from the eval or train split
# * The `caption` field has the description of the audio: "The low quality recording features a ballad song that contains sustained strings, mellow piano melody and soft female vocal singing over it. It sounds sad and soulful, like something you would hear at Sunday services."

# %% [markdown]
# ## Interactive explorer
#
# We can use [Gradio](https://gradio.app/), an open-source library to build ML demos, to build an interface in which the user selects the index of the sample and can then listen to the audio and read the caption. Gradio has a nice `Interface` class which has three key components
# * `inputs`: specifies which are the input components. In this case, we'll want a slider that will represent the index.
# * `outputs`: the output components. In this case, we want an audio and a textarea
# * Any inference function that receives the `inputs` type and outputs the `outputs` types.
#
# Let's see it in action!

# %%
import gradio as gr

def get_example(idx):
    ex = ds[idx]
    return ex['audio']['path'], ex['caption']

gr.Interface(
    get_example,
    inputs=gr.Slider(0, len(ds) - 1, value=0, step=1),
    outputs=['audio', 'textarea'],
    allow_flagging="never",
    live=True
).launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://8298a4bb-b1ac-482d.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://8298a4bb-b1ac-482d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# That's it! I hope you find this notebook useful!
#
# Hugs!🤗
